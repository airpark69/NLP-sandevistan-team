# %% [markdown]
# ## 핵심 아이디어
# 1. 메뉴명을 명사 단위로 토큰화
# 2. 토큰화한 메뉴명을 빈도분석
# 3. 빈도 내림차순으로 나열한 뒤 특정 비율의 토큰을 채택
# 4. 채택한 토큰으로 끝나는 메뉴명을 토큰 카테고리로 분류
#
# ## 간단하지만 강력한 알고리즘
# 대부분 한국어 메뉴명이 분류로 종결된다는 특성을 이용하였습니다
# ex)오곡라떼 => '라떼'라는 분류명으로 종결됨
#
# 따라서 이렇게 1차 분류를 시도해보고, 오분류되었거나 미분류된 음식명을 2차 분류해보는건 어떠할지?

# %%
# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 48.0 MB/s eta 0:00:00
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (465 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.6/465.6 KB 31.4 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.8/dist-packages (from konlpy) (4.9.2)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.8/dist-packages (from konlpy) (1.21.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from JPype1>=0.7.0->konlpy) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->JPype1>=0.7.0->konlpy) (3.0.9)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.1 konlpy-0.6.0

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

# %%
# 데이터 임포팅 
df = pd.read_csv('menu_concated_v1.4')
df.dropna(inplace=True)
menu_list = df['menu'].tolist()

# %%
# 명사 단위 토큰화
from konlpy.tag import Okt
from tqdm import tqdm

t = Okt()
menu_list = [t.nouns(word) for word in tqdm(menu_list)]
# Out:
# 100%|██████████| 51437/51437 [00:41<00:00, 1227.60it/s]

# %% [markdown]
# Okt를 통한 명사 구분의 경우 [자연, 산모, 듬회] 같이 도메인에 맞지 않는 토큰화가 보인다.
#
# 알고리즘의 논리가 명사 분리부터 시작하기 때문에, 이 문제 해결부터 해야한다고 판단한다
#
# 2023-01-17
#
# - [해결] 빈도수 비율 없이, 그냥 맨 뒷 토큰을 사용해보는 실험 해보기
#
# - [해결] soynlp를 통한 토큰화 시도

# %%
df
# Out:
#        Unnamed: 0    식당명                  메뉴명   메뉴가격      menu
# 0               0   신풍식당                   정식   5000        정식
# 1               1    부창루                  짜장면   5000       짜장면
# 2               2    부창루                   짬뽕   6000        짬뽕
# 3               3    부창루                   우동   6000        우동
# 4               4    부창루                   울면   6000        울면
# ...           ...    ...                  ...    ...       ...
# 51432       51432  차이나프로    철판통후추소고기(대/4~5인분)  70000  철판통후추소고기
# 51433       51433  차이나프로    삼선해물누룽지탕(대/4~5인분)  50000  삼선해물누룽지탕
# 51434       51434  차이나프로  비풍당새우(대/4~5인분/저녁메뉴)  55000     비풍당새우
# 51435       51435  차이나프로        파인새우(대/4~5인분)  48000      파인새우
# 51436       51436  차이나프로        좌종당계(대/4~5인분)  48000      좌종당계
#
# [51437 rows x 5 columns]

# %% [markdown]
# ## 표준 데이터셋과의 match 비율을 통한 빈도수 상위 %에 대한 임계점 파악하기

# %%
corpus = pd.read_csv('/content/Kor_standard_menu_clean.csv')
text = corpus['title']

# %%
corpus
# Out:
#       Unnamed: 0              title large_category category
# 0              0        케이크 너트 브라우니        빵 및 과자류      케이크
# 1              1     케이크 녹차바스크치즈케이크        빵 및 과자류      케이크
# 2              2      케이크 녹차티라미수케이크        빵 및 과자류      케이크
# 3              3       케이크 뉴욕 치즈케이크        빵 및 과자류      케이크
# 4              4  케이크 뉴욕슈치즈케이크 (조각)        빵 및 과자류      케이크
# ...          ...                ...            ...      ...
# 8298        8298              청포묵무침         생채·무침류    청포묵무침
# 8299        8299             치커리겉절이         생채·무침류   치커리겉절이
# 8300        8300          파래무침 파래 무         생채·무침류     파래무침
# 8301        8301               짜장소스        장류, 양념류     짜장소스
# 8302        8302               카레소스        장류, 양념류     카레소스
#
# [8303 rows x 4 columns]

# %%
df['tokens'] = menu_list

# %%
from collections import Counter

# Counter 객체는 리스트요소의 값과 요소의 갯수를 카운트 하여 저장하고 있습니다.
# 카운터 객체는 .update 메소드로 계속 업데이트 가능합니다.
word_counts = Counter()

# 토큰화된 각 리뷰 리스트를 카운터 객체에 업데이트 합니다. 
df['tokens'].apply(lambda x: word_counts.update(x))

# 가장 많이 존재하는 단어 순으로 10개를 나열합니다
word_counts.most_common(10)
# Out:
# [('치즈', 1836),
#  ('치킨', 1403),
#  ('세트', 1367),
#  ('추가', 1298),
#  ('라떼', 977),
#  ('볶음', 850),
#  ('밥', 824),
#  ('새우', 815),
#  ('크림', 796),
#  ('탕', 791)]

# %%
len(word_counts)
# Out:
# 12046

# %%
std_category = corpus['category'].unique()

# %%
std_category[0]
# Out:
# '케이크'

# %%
# 빈도 상위 10퍼센트의 토큰만 선택
cut_line = int(len(word_counts) / 10)

# 단, 두글자 이상인 토큰만 선택 (1글자 토큰은 결과를 곱창내놓았음;; 하지만 불용어 설정을 잘 한다면??)
outliner_vocab = word_counts.most_common(cut_line)

# %%
int(len(word_counts) * 0.2)
# Out:
# 2409

# %%
'치즈' in std_category
# Out:
# True

# %%
def cut_line_test(cut_num):
  # 빈도 상위 cut_num 퍼센트의 토큰만 선택
  cut_line = int(len(word_counts) * cut_num)
  outliner_vocab = word_counts.most_common(cut_line)

  std_match_dict = {}

  for out in outliner_vocab:
    if out[0] in std_category:
      std_match_dict[out[0]] = 1
    else:
      std_match_dict[out[0]] = 0

  match_list = list(std_match_dict.values())
  print(f"match 비율 : {match_list.count(1) / len(match_list)}")

# %%
cut_line_test(0.1)
cut_line_test(0.2)
cut_line_test(0.3)
# Out:
# match 비율 : 0.11627906976744186
# match 비율 : 0.0767953507679535
# match 비율 : 0.057569886520896764

# %%
cut_line_test(0.4)
cut_line_test(0.5)
cut_line_test(0.6)
# Out:
# match 비율 : 0.0460772104607721
# match 비율 : 0.038851070894902875
# match 비율 : 0.0326553203265532

# %%
cut_line_test(0.01)
cut_line_test(0.001)
cut_line_test(0.0001)
# Out:
# match 비율 : 0.225
# match 비율 : 0.25
# match 비율 : 1.0

# %% [markdown]
# 결론
#
# - match 비율이 상당히 낮다. 즉, 전국5도 데이터에서의 토큰으로는 표준 데이터셋을 설명하기 힘들다는 의미라고 생각할 수도 있다.
#
# - 임계점을 낮출 경우, 전체 범주가 늘어나기 때문에 match 비율이 줄어드는 것은 설명할 수 있다. 하지만, 반대로 임계점을 올렸을 경우에도 match 비율이 1에 가까워져야 하지만 0.25 정도까지만 오르는 것을 보면 결국 표준 데이터셋이 더 설명력이 크다고 볼 수 있다고 판단한다
#
# - 표준 데이터셋을 사전처럼 사용해서 분류하는게 더 정확할 수도 있다는 판단이 들었다
#
# - 빈도수 관련 언어모델의 한계를 생각해보면, 빈도수 비율을 활용한 접근법은 다시 재고해봐야 할 필요성을 느낀다

# %% [markdown]
# ## '듬' 문제 - 토큰화의 오류 해결

# %%
for i, token_list in enumerate(df['tokens']):
  for token in token_list:
    if '듬' in token:
      print(df['menu'].iloc[i])
      print(token_list)
# Out:
# 모듬회
# ['모듬회']
# 모듬튀김
# ['듬', '튀김']
# 건어물모듬
# ['건어물', '듬']
# 모듬
# ['모듬']
# 모듬양장피
# ['듬', '양장', '피']
# 조개모듬구이
# ['조개', '듬', '구이']
# 모듬회스페셜
# ['듬회', '스페셜']
# 삼영모듬회스페셜
# ['듬회', '스페셜']
# 삼영해산물모듬스페셜
# ['해산물', '듬', '스페셜']
# 자연산모듬회
# ['자연', '산모', '듬회']
# 모듬해물
# ['듬', '해물']
# 해물모듬
# ['해물', '듬']
# 해물모듬물회
# ['해물', '듬', '물회']
# 살고기모듬수육
# ['살', '기모', '듬', '수육']
# 모듬수육
# ['듬', '수육']
# 모듬전
# ['모듬전']
# 모듬회코스
# ['듬회', '코스']
# 한우모듬
# ['한우', '듬']
# 모듬양곱창
# ['듬', '곱창']
# 모듬스테이크
# ['듬', '스테이크']
# 모듬전골
# ['듬', '전골']
# 고기듬뿍김치찌개
# ['고기', '듬뿍', '김치찌개']
# 해산물모듬
# ['해산물', '듬']
# 모듬양념구이
# ['듬', '양념', '구이']
# 연어모듬회
# ['연어', '듬회']
# 특모듬
# ['특모듬']
# 고급어종모듬
# ['고급', '종', '듬']
# 모듬조개전복
# ['듬', '조개', '전복']
# 모듬조개
# ['듬', '조개']
# 생선모듬초밥
# ['생선', '듬', '초밥']
# 모듬스페샬
# ['모듬스페샬']
# 고기듬북김치찌개
# ['고기', '듬북', '김치찌개']
# 모듬오뎅탕
# ['듬', '오뎅', '탕']
# 모듬감자튀김
# ['듬', '감자', '튀김']
# 순대모듬
# ['듬']
# 모듬국밥
# ['듬', '국밥']
# 모듬생선구이
# ['듬', '생선', '구이']
# 모듬생선회삿뽀로
# ['듬', '생선회', '삿뽀로']
# 모듬생선회오타루
# ['듬', '생선회', '오타루']
# 모듬생선회오도리
# ['듬', '생선회', '도리']
# 모듬초밥개
# ['듬', '초밥']
# 모듬꼬치세트
# ['듬', '꼬치', '세트']
# 모듬후라이
# ['듬후', '라이']
# 모듬회대
# ['듬회']
# 모듬회중
# ['듬', '회중']
# 모듬회소
# ['듬', '회소']
# 돼지고기듬뿍김치찜
# ['돼지고기', '듬뿍', '김치', '찜']
# 모듬막창구이
# ['듬', '막창구이']
# 따로모듬국밥
# ['듬', '국밥']
# 모듬구이
# ['듬', '구이']
# 일돈특수모듬
# ['돈', '특수', '듬']
# 일돈양념모듬
# ['돈', '양념', '듬']
# 특수모듬양념모듬
# ['특수', '듬', '양념', '듬']
# 특수모듬양념모듬
# ['특수', '듬', '양념', '듬']
# 양식모듬회
# ['양식', '듬회']
# 모듬물회
# ['듬', '물회']
# 모듬만두
# ['듬']
# 모듬세트
# ['듬', '세트']
# 모듬곰탕
# ['듬', '곰탕']
# 참다랑어모듬
# ['참다랑어', '듬']
# 참치모듬초밥
# ['참치', '듬', '초밥']
# 참치모듬눈다랑어부위
# ['참치', '듬눈', '다랑어', '부위']
# 모듬초밥
# ['듬', '초밥']
# 오늘의모듬초밥
# ['오늘', '듬', '초밥']
# 특모듬국밥
# ['특모듬', '국밥']
# 고구마치즈스틱모듬감자
# ['고구마', '치즈스틱', '듬', '감자']
# 모듬해물짬뽕
# ['듬', '해물짬뽕']
# 매듬해불짬뽕밥
# ['듬해불', '짬뽕', '밥']
# 해삼모듬
# ['해삼', '듬']
# 고래모듬
# ['고래', '듬']
# 모듬회특
# ['모듬회특']
# 자연산모듬회특
# ['자연', '산모', '듬회특']
# 예담모듬세트
# ['예담', '듬', '세트']
# 모듬가라아게
# ['듬', '가라아게']
# 모듬해산물
# ['듬', '해산물']
# 특모듬보쌈
# ['특모듬', '보쌈']
# 모듬새우튀김
# ['듬', '새우', '튀김']
# 모듬생선회
# ['듬', '생선회']
# 따로모듬
# ['듬']
# 모듬수제돈까스
# ['듬', '돈까스']
# 모듬사시미
# ['듬', '사시미']
# 모듬까스
# ['모듬까스']
# 제주특모듬
# ['제주', '특모듬']
# 모듬버섯
# ['듬', '버섯']
# 덕포모듬회
# ['덕포모듬회']
# 튀김모듬
# ['튀김', '듬']
# 특모듬회
# ['특모듬회']
# 삼겹파티모듬
# ['삼겹', '파티', '듬']
# 버섯모듬
# ['버섯모', '듬']
# 모듬소세지
# ['듬', '소세지']
# 모듬김밥
# ['듬', '김밥']
# 신선모듬사시미
# ['신선', '듬', '사시미']
# 해물모듬철판구이
# ['해물', '듬', '철판', '구이']
# 용궁해물모듬
# ['용궁', '해물', '듬']
# 기본어종모듬
# ['기본', '종', '듬']
# 참돔어종모듬
# ['참돔', '종', '듬']
# 돌돔어종모듬
# ['돌돔', '종', '듬']
# 양갈비모듬
# ['갈비', '듬']
# 등갈비모듬
# ['등', '갈비', '듬']
# 계절모듬회
# ['계절', '듬회']
# 모듬해물된장죽
# ['듬', '해물', '된장', '죽']
# 모듬해물죽
# ['듬', '해물', '죽']
# 모듬포안주
# ['듬포', '안주']
# 생고기모듬
# ['생', '고기', '듬']
# 고급모듬회
# ['고급', '듬회']
# 모듬순대
# ['듬', '순대']
# 딤섬모듬
# ['딤섬', '듬']
# 모듬한판
# ['듬', '한판']
# 해물모듬짬뽕
# ['해물', '듬', '짬뽕']
# 특수부위모듬
# ['특수', '부위', '듬']
# 흑돼지모듬
# ['돼지', '듬']
# 순두부모듬전골
# ['순두부', '듬', '전골']
# 생등심돈까스모듬
# ['생', '등심', '돈까스', '듬']
# 모듬활어회
# ['듬', '활어회']
# 모듬감자
# ['듬', '감자']
# 스페셜모듬튀김
# ['스페셜', '듬', '튀김']
# 오징어모듬회
# ['오징어', '듬회']
# 생연어모듬회
# ['생', '연어', '듬회']
# 모듬까스안주
# ['듬까스', '안주']
# 모듬어묵탕
# ['듬', '어묵', '탕']
# 모듬타파스
# ['듬', '타파스']
# 모듬술국
# ['듬', '술국']
# 명품모듬전
# ['명품', '듬전']
# 돼지모듬
# ['돼지', '듬']
# 생선구이모듬
# ['생선', '듬']
# 모듬해물사시미
# ['듬', '해물', '사시미']
# 모듬꼬치
# ['듬', '꼬치']
# 불꽃모듬
# ['불꽃', '듬']
# 피자주문시치즈듬뿍
# ['피자', '치즈', '듬뿍']
# 제주모듬
# ['듬']
# 과일모듬
# ['과일', '듬']
# 돼지특수모듬
# ['돼지', '특수', '듬']
# 돼지특수모듬추가
# ['돼지', '특수', '듬', '추가']
# 혼마구로모듬
# ['혼', '마구로', '듬']
# 참치회모듬
# ['참치회', '듬']
# 모듬철판볶음밥
# ['듬', '철판', '볶음밥']
# 츠키지풍모듬초밥
# ['츠키지풍모듬', '초밥']
# 한우특수모듬
# ['한우', '특수', '듬']
# 모듬야채
# ['듬', '야채']
# 제주모듬한판
# ['듬', '한판']
# 모듬치즈플래터
# ['듬', '치즈', '플래터']
# 기타모듬
# ['듬']
# 가타추가류모듬
# ['가타', '추가', '류', '듬']
# 실속모듬세트
# ['실속', '듬', '세트']
# 고급뱃살모듬세트
# ['고급', '뱃살', '듬', '세트']
# 인모듬
# ['인모듬']
# 수제모듬소세지
# ['듬', '소세지']
# 모듬소시지
# ['듬', '소시지']
# 모듬볶음밥
# ['듬', '볶음밥']
# 그릴모듬떡갈비
# ['그릴', '듬', '떡갈비']
# 사계절철별미모듬오뎅탕
# ['사계절', '철', '미모', '듬', '오뎅', '탕']
# 조개모듬
# ['조개', '듬']
# 장어모듬
# ['장어', '듬']
# 모듬찜류
# ['모듬찜류']
# 모듬튀김류
# ['듬', '튀김', '류']
# 모듬피쉬볼
# ['듬', '피쉬', '볼']
# 양파듬뿍돈까스
# ['양파', '듬뿍', '돈까스']
# 치즈듬뿍감자튀김
# ['치즈', '듬뿍', '감자', '튀김']
# 양파듬뿍카츠
# ['양파', '듬뿍', '카츠']
# 와규모듬추가
# ['규모', '듬', '추가']
# 모듬오뎅
# ['듬', '오뎅']
# 모듬꼬지
# ['모듬꼬']
# 모듬조개구이
# ['듬', '개구']
# 모듬한접시
# ['듬', '접시']
# 모듬고기
# ['듬', '고기']
# 계절모듬사시미
# ['계절', '듬', '사시미']
# 모듬과일
# ['듬', '과일']
# 모듬소시지구이
# ['듬', '소시지', '구이']
# 모듬사시미벤또
# ['듬', '사시미', '벤또']
# 오덕모듬돈까스
# ['오덕', '듬', '돈까스']
# 참치모듬
# ['참치', '듬']
# 유기농종모듬현미선물세트
# ['유기농', '종', '듬', '현미', '선물', '세트']
# 모듬꼬마김밥
# ['듬', '꼬마', '김밥']
# 모듬꼬지구이종
# ['듬꼬', '이종']
# 모듬고로케
# ['듬', '고로케']
# 모듬생고기
# ['듬생', '고기']
# 모듬어묵핫바
# ['듬', '어묵', '핫바']
# 남도모듬
# ['남도', '듬']
# 갈비특수부위모듬
# ['갈비', '특수', '부위', '듬']
# 닭모듬꼬치종
# ['닭', '듬', '꼬치', '종']
# 모듬소세지웨지감자
# ['듬', '소세지', '웨', '감자']
# 듬뿍골뱅이무침
# ['듬뿍', '골뱅이']
# 모듬양곱찰
# ['듬', '곱찰']
# 모듬조개찜
# ['듬', '조개찜']
# 모듬회초장인
# ['듬회', '초장']
# 조개구이모듬회해물라면치즈
# ['개구', '듬회', '해물', '라면', '치즈']
# 모듬회해물탕
# ['듬회', '해물탕']
# 모듬회곰장어
# ['듬회', '곰장어']
# 모듬회물회매운탕
# ['듬회', '물회', '매운탕']
# 모듬회새우구이
# ['듬회']
# 스페셜참치모듬회
# ['스페셜', '참치', '듬회']
# 쿄우스페셜모듬회
# ['쿄', '스페셜', '듬회']
# 와규모듬구이
# ['규모', '듬', '구이']
# 모듬냉채
# ['듬', '냉채']
# 생선모듬찜
# ['생선', '듬찜']
# 태국식모듬튀김
# ['태국', '듬', '튀김']
# 해물듬뿍부추전
# ['해물', '듬뿍', '부추', '전']
# 치즈듬뿍콤비네이션
# ['치즈', '듬뿍', '콤비네이션']
# 차즈듬뿍콤비네이션
# ['차', '듬뿍', '콤비네이션']
# 모듬치킨
# ['듬', '치킨']
# 모듬해물탕
# ['듬', '해물탕']
# 오덕모듬까스
# ['오덕', '듬까스']
# 특수부위생고기모듬
# ['특수', '부위', '생', '기모', '듬']
# 모듬새우초밥
# ['듬', '새우', '초밥']
# 참치뱃살모듬
# ['참치', '뱃살', '듬']
# 모듬쿠시카츠
# ['듬', '쿠시카츠']
# 해물모듬소
# ['해물', '듬소']
# 모듬치즈과일
# ['듬', '치즈', '과일']
# 뚱대삼이모듬
# ['뚱대삼이모듬']
# 한돈모듬한판
# ['돈', '듬', '한판']
# 야채모듬구이
# ['야채', '듬', '구이']
# 바나나듬뿍
# ['바나나', '듬뿍']
# 스페샬모듬
# ['스페샬모듬']
# 생모듬한판
# ['생모', '듬', '한판']
# 모듬손만두
# ['듬손']
# 활어모듬회
# ['활', '듬회']
# 젠닌모듬오뎅탕
# ['젠', '닌모듬', '오뎅', '탕']
# 대게모듬꼬치
# ['대게', '듬', '꼬치']
# 모듬생선
# ['듬', '생선']
# 모듬사시미정식
# ['듬', '사시미', '정식']
# 한우생모듬세트
# ['한우', '생모', '듬', '세트']
# 모듬고노와다
# ['듬', '노']
# 소미모듬세트
# ['미모', '듬', '세트']
# 모듬스팸후라이
# ['듬스팸', '후', '라이']
# 꾼모듬튀김
# ['꾼', '듬', '튀김']
# 꾼모듬사시미
# ['꾼', '듬', '사시미']
# 꾼모듬초밥
# ['꾼', '듬', '초밥']
# 모듬튀김우동
# ['듬', '튀김', '우동']
# 모듬포테이토
# ['듬', '포테이토']
# 모듬수육추가
# ['듬', '추가']
# 모듬햄짜글이
# ['모듬햄짜글']
# 모듬카츠정식
# ['듬', '카츠', '정식']
# 순대모듬전골
# ['듬', '전골']
# 활랍스터모듬사시미
# ['활', '랍스터', '듬', '사시미']
# 스페셜활랍스터모듬사미
# ['스페셜', '활', '랍스터', '듬', '사미']
# 키이로모듬회
# ['키', '듬회']
# 깐풍모듬해산물
# ['풍모', '듬', '해산물']
# 모듬짬뽕전골
# ['듬', '짬뽕', '전골']
# 청경채모듬버섯볶음
# ['청경채', '듬', '버섯', '볶음']
# 모듬치킨세트
# ['듬', '치킨', '세트']
# 산구모듬
# ['산', '구모', '듬']
# 한상가득모듬
# ['상가', '득', '듬']
# 특별한상가득모듬
# ['상가', '득', '듬']
# 생선모듬구이
# ['생선', '듬', '구이']
# 왕모듬물회
# ['왕모', '듬', '물회']
# 모듬사시미종
# ['듬', '사시미', '종']
# 해물모듬숙회
# ['해물', '듬숙', '회']
# 인혼술모듬
# ['인혼술모듬']
# 고니듬뿍알탕
# ['고니', '듬뿍', '알탕']
# 생크림모듬
# ['생크림', '듬']
# 무스모듬
# ['무스', '듬']
# 해물모듬중
# ['해물', '듬']
# 해물모듬대
# ['해물', '듬']
# 바닷가모듬회회추가시
# ['바닷가', '듬회회추', '가시']
# 돼지듬뿍김치찌개
# ['돼지', '듬뿍', '김치찌개']
# 스페셜모듬
# ['스페셜', '듬']
# 계양간모듬
# ['계양', '듬']
# 모듬쏘세지
# ['듬']
# 각종모듬튀김
# ['각종', '듬', '튀김']
# 에그듬뿍샌드위치
# ['듬뿍', '샌드위치']
# 모듬코스
# ['듬', '코스']
# 모듬플레터
# ['듬', '레터']
# 모듬타파스종
# ['듬', '타파스', '종']
# 독일모듬소세지
# ['독일', '듬', '소세지']
# 모듬볼
# ['모듬볼']
# 제철모듬사시미
# ['제철', '듬', '사시미']
# 모듬셋트
# ['모듬셋트']
# 듬뿍야채쫄쫄면
# ['듬뿍', '야채', '쫄', '쫄면']
# 평범해서맛있는모듬
# ['듬']
# 선장해물모듬
# ['선장', '해물', '듬']
# 모듬브르스게타
# ['듬브르', '스게', '타']
# 새우모듬초밥
# ['새우', '듬', '초밥']
# 더랭햄그릴모듬
# ['더랭햄그릴모듬']
# 모듬눈꽃감자튀김
# ['듬', '눈꽃', '감자', '튀김']
# 일반모듬
# ['듬']
# 수제모듬어묵
# ['듬', '어묵']
# 간편한국탕용모듬어묵
# ['간편', '한국', '탕', '용모', '듬', '어묵']
# 모듬튀밥세트
# ['듬', '튀밥', '세트']
# 버섯야채모듬사리
# ['버섯', '야채', '듬', '사리']
# 모듬야채볶음
# ['듬', '야채', '볶음']
# 모듬버섯볶음
# ['듬', '버섯', '볶음']
# 특모듬초밥
# ['특모듬', '초밥']
# 고급한우모듬
# ['고급', '우모', '듬']
# 모듬구이스페셜
# ['듬', '스페셜']
# 편육모듬
# ['편육', '듬']
# 모듬중
# ['듬']
# 모듬대
# ['듬']
# 양곱창모듬
# ['곱창', '듬']
# 한우명품모듬
# ['한우', '명품', '듬']
# 싱싱모듬회
# ['싱싱모듬회']
# 새우모듬튀김
# ['새우', '듬', '튀김']
# 모듬돈까스
# ['듬', '돈까스']
# 모듬떡볶이
# ['듬', '떡볶이']
# 특수모듬
# ['특수', '듬']
# 모듬스페셜참치랍스타
# ['듬', '스페셜', '참치', '랍', '스타']
# 생딸기듬뿍우유생크림케이크
# ['생', '딸기', '듬뿍', '우유', '생크림', '케이크']
# 블루베리요거트듬뿍케이크
# ['블루베리', '요거트', '듬뿍', '케이크']
# 촉촉한블루베리듬뿍쉬폰
# ['블루베리', '듬뿍', '쉬폰']
# 모듬개
# ['듬']
# 치즈듬뿍피자
# ['치즈', '듬뿍', '피자']
# 어묵모듬세트
# ['어묵', '듬', '세트']
# 전골야채모듬
# ['전골', '야채', '듬']
# 생선모듬
# ['생선', '듬']
# 마늘듬뿍닭볶음탕
# ['마늘', '듬뿍', '닭볶음탕']
# 알짜모듬세트
# ['알짜', '듬', '세트']
# 모듬건어물
# ['듬', '건어물']
# 모듬사시미코스인
# ['듬', '사시미', '코스']
# 모듬나초
# ['듬', '나초']
# 모듬리필참치
# ['듬리필', '참치']
# 왕새우모듬튀김
# ['왕새우', '듬', '튀김']
# 딸기듬뿍와플
# ['딸기', '듬뿍', '와플']
# 종모듬꼬치
# ['종', '듬', '꼬치']
# 제주흑돼지부위별모듬
# ['제주', '돼지', '부위', '듬']
# 모듬바베큐
# ['듬', '바베큐']
# 무듬만두
# ['무듬만']
# 철판모듬소세지
# ['철판', '듬', '소세지']
# 계절모듬과일
# ['계절', '듬', '과일']
# 번모듬
# ['번모듬']
# 제철과일듬뿍에이드
# ['제철', '과일', '듬뿍', '이드']
# 노상모듬쌀국수
# ['노상', '듬', '쌀국수']
# 매운해장모듬쌀국수
# ['장모', '듬', '쌀국수']
# 퐁당모듬떡볶이
# ['퐁당', '듬', '떡볶이']
# 모듬포
# ['모듬포']
# 모듬전골뱅이
# ['듬', '골뱅이']
# 모듬전오징어숙회
# ['듬', '오징어', '숙회']
# 한돈생고기모듬
# ['돈생', '고기', '듬']
# 찹쌀모듬순대
# ['찹쌀', '듬', '순대']
# 해초모듬회덮밥
# ['해초', '듬', '회덮밥']
# 모듬내장
# ['듬', '내장']
# 모듬특
# ['모듬특']
# 통낙지모듬해물쟁반자장면
# ['통', '낙지', '듬', '해물', '쟁반자장']
# 모듬버섯덮밥
# ['듬', '버섯', '밥']
# 모듬해물누룽지탕
# ['듬', '해물', '누룽지', '탕']
# 철판모듬해물팔보채
# ['철판', '듬', '해물', '팔보채']
# 모듬한우탕
# ['듬', '한우', '탕']
# 모듬해물찜
# ['듬', '해물찜']
# 돼지부속모듬
# ['돼지', '부속', '듬']
# 실속모듬
# ['실속', '듬']
# 모듬사리
# ['듬', '사리']
# 모듬회무침
# ['듬회']
# 해산물모듬회
# ['해산물', '듬회']
# 모듬생선포장
# ['듬', '생선', '포장']
# 한우스페셜모듬
# ['한우', '스페셜', '듬']
# 마른안주모듬
# ['듬']
# 몸보신모듬세트
# ['몸', '보신', '듬', '세트']
# 모듬버섯회
# ['듬', '버섯', '회']
# 돈특수모듬
# ['돈', '특수', '듬']
# 모듬순대한접시
# ['듬', '접시']
# 직화쭈꾸미모듬안주
# ['직화', '쭈꾸미', '듬', '안주']
# 모듬참치회한접시
# ['듬', '참치회', '접시']
# 잔치모듬전
# ['잔치', '듬전']
# 모듬생선초밥
# ['듬', '생선', '초밥']
# 청정모듬순대
# ['청정', '듬', '순대']
# 반곡역한우특수부위모듬
# ['반곡역', '한우', '특수', '부위', '듬']
# 스페셜모듬치즈
# ['스페셜', '듬', '치즈']
# 산지직송해산물모듬
# ['산지', '직송', '해산물', '듬']
# 모듬생선조림
# ['듬', '생선', '조림']
# 한우모듬구이
# ['우모', '듬', '구이']
# 유버모듬맛감자튀김
# ['유', '버모듬', '맛', '감자', '튀김']
# 모듬감튀
# ['모듬감튀']
# 모듬소세지감튀
# ['듬', '소세지', '감']
# 한우모듬자연산송이버섯세트
# ['우모', '듬', '연산', '송이버섯', '세트']
# 명품모듬자연산송이버섯세트
# ['명품', '듬', '연산', '송이버섯', '세트']
# 문어모듬보쌈
# ['문어', '듬', '보쌈']
# 모듬보족
# ['모듬보족']
# 모듬닭갈비
# ['듬', '닭갈비']
# 모듬뱅이
# ['모듬뱅']
# 흙마늘모듬구이
# ['흙', '마늘모', '듬', '구이']
# 치즈모듬감자튀김
# ['치즈', '듬', '감자', '튀김']
# 모듬해삼
# ['듬', '해삼']
# 제우스모듬
# ['제우스', '듬']
# 한우모듬삼창
# ['우모', '듬', '삼창']
# 모듬쌀찐빵개
# ['듬쌀', '찐빵']
# 모듬수육소
# ['듬', '소']
# 모듬수육대
# ['듬', '수육']
# 모듬전골중
# ['듬', '전골']
# 모듬전골대
# ['듬', '전골']
# 치즈듬뿍순꿀꽃
# ['치즈', '듬뿍', '꿀꽃']
# 밤이듬뿍맘모스
# ['밤', '듬뿍', '맘모스']
# 하트를듬뿍담은쇼콜라스퀘어
# ['하트', '듬뿍', '쇼콜라', '스퀘어']
# 모듬바베큐플레이트
# ['듬', '바베큐', '플레이', '트']
# 즉석모듬떡볶이
# ['듬', '떡볶이']
# 명태회모듬수육
# ['명태', '회모', '듬', '수육']
# 모듬소세지구이
# ['듬', '소세지', '구이']
# 해물듬뿍파전
# ['해물', '듬뿍', '파전']
# 생선삼모듬
# ['생선', '듬']
# 전하면모듬전
# ['전하', '듬전']
# 모듬닭사리
# ['듬닭', '사리']
# 고기듬뿍카레라이스
# ['고기', '듬뿍', '카레라이스']
# 모듬삼창
# ['듬', '삼창']
# 매니아모듬튀김
# ['매니아', '듬', '튀김']
# 모듬어묵탕우동사리
# ['듬', '어묵', '탕', '우동', '사리']
# 태권모듬떡볶이세트
# ['태권', '듬', '떡볶이', '세트']
# 모듬종소스
# ['듬종', '소스']
# 모듬회큰형
# ['모듬회큰형']
# 모듬회작은형
# ['듬회', '형']
# 모듬회막내
# ['듬회', '막내']
# 모듬회세트
# ['듬회', '세트']
# 전복모듬물회
# ['전복', '듬', '물회']
# 이베리코모듬
# ['베리', '코모', '듬']
# 모듬해물한판
# ['듬', '해물', '한판']
# 모듬부대찌개
# ['듬', '부대찌개']
# 꽃돼지모듬
# ['꽃', '돼지', '듬']
# 모듬라볶이
# ['듬', '라볶이']
# 모듬꼬치구이
# ['듬', '꼬치', '구이']
# 쇠고기듬뿍볶음밥음료
# ['쇠고기', '듬뿍', '볶음밥', '음료']
# 쇠고기듬뿍팬볶이
# ['쇠고기', '듬뿍', '팬', '볶이']
# 세트메뉴모듬
# ['세트', '메뉴', '듬']
# 크런치모듬튀김
# ['크런치', '듬', '튀김']
# 고기듬뿍물쫄면
# ['고기', '듬뿍', '물', '쫄면']
# 미돈모듬안주
# ['미돈', '듬', '안주']
# 특수부속모듬
# ['특수', '부속', '듬']
# 알모듬
# ['알모듬']
# 모듬순대대
# ['듬', '순대']
# 모듬순대중
# ['듬', '대중']
# 모듬샤브샤브칼국수
# ['듬', '샤브샤브', '칼국수']
# 모듬만두비빔만두
# ['듬', '비빔']
# 모듬튀김세트
# ['듬', '튀김', '세트']
# 듬뿍콘버터
# ['듬뿍', '콘', '버터']
# 모듬생선회대
# ['듬', '생선회']
# 모듬생선구이돌솥밥
# ['듬', '생선', '이돌', '솥밥']
# 흑염소생양념모듬숯불구이
# ['염소', '생', '양념', '듬', '숯불', '구이']
# 흑염소생모듬숯불구이
# ['염소', '생모', '듬', '숯불', '구이']
# 살치살갈비살등심모듬인셋트
# ['살', '갈비살', '등심', '모', '듬인셋트']
# 등심모듬
# ['등심', '듬']
# 모듬전육전동태전굴전동그랑땡호
# ['듬', '동태', '굴', '동그랑땡', '호']
# 가마보꼬모듬오뎅탕
# ['가마보꼬', '듬', '오뎅', '탕']
# 번돈까스모듬소세지
# ['번', '돈까스', '듬', '소세지']
# 모듬튀김한판
# ['듬', '튀김', '한판']
# 생크림듬뿍스콘
# ['생크림', '듬뿍', '스콘']
# 치즈듬뿍떡볶이
# ['치즈', '듬뿍', '떡볶이']
# 미니모듬회
# ['미니모', '듬회']
# 모듬덴뿌라
# ['듬', '덴뿌라']
# 마늘빵모듬
# ['마늘빵', '듬']
# 참치와활어모듬
# ['참치', '활', '듬']
# 활어모듬
# ['활', '듬']
# 참치모듬사시미
# ['참치', '듬', '사시미']
# 활어모듬사시미
# ['활', '듬', '사시미']
# 모듬전식
# ['듬', '전식']
# 세트모듬전식
# ['세트', '듬', '전식']
# 고기모듬
# ['듬']
# 알뜰모듬한상소
# ['알뜰', '듬', '상소']
# 푸짐모듬한상소
# ['짐', '듬', '상소']
# 항정가브리갈매기특수모듬
# ['항', '정가', '브리', '갈매기', '특수', '듬']
# 고기듬뿍꿀갈비비빔밥된장찌개
# ['듬뿍', '꿀', '갈비', '비빔밥', '된장찌개']
# 고기듬뿍매운꿀갈비비빔밥된장찌개
# ['듬뿍', '꿀', '갈비', '비빔밥', '된장찌개']
# 한우암소모듬
# ['우암', '듬']
# 특선모듬
# ['특선', '듬']
# 특선모듬세트
# ['특선', '듬', '세트']
# 새우듬뿍멘보샤
# ['새우', '듬뿍', '멘보샤']
# 닭뽁이모듬사리
# ['닭', '뽁이모듬', '사리']
# 까뽁이모듬사리
# ['까뽁이모듬', '사리']
# 크림뽁이모듬사리
# ['크림', '뽁이모듬', '사리']
# 치즈닭뽁이모듬사리
# ['치즈', '닭', '뽁이모듬', '사리']
# 알마니닭뽁이모듬사리
# ['알', '닭', '뽁이모듬', '사리']
# 명품특수모듬
# ['명품', '특수', '듬']
# 소고기모듬구이
# ['소고기', '듬', '구이']
# 곱창모듬구이
# ['곱창', '듬', '구이']
# 특양모듬구이
# ['특양모듬', '구이']
# 허니모듬포테이토
# ['허니', '듬', '포테이토']
# 돈육모듬
# ['돈육', '듬']
# 치킨모듬세트
# ['치킨', '듬', '세트']
# 모듬족발
# ['듬', '족발']
# 꾼모듬요리
# ['꾼', '듬', '요리']
# 모듬곱창볶음
# ['듬', '곱창', '볶음']
# 모듬꼬치종
# ['듬', '꼬치', '종']
# 쌀찐빵모듬한상자
# ['쌀', '찐빵', '듬', '상자']
# 뒷고기모듬
# ['듬']
# 생모듬
# ['생모', '듬']
# 모듬치즈라볶이
# ['듬', '치즈', '라볶이']
# 모듬수육전골
# ['모듬수육전골']
# 베이컨모듬구이
# ['베이컨', '듬', '구이']
# 내장모듬
# ['장모', '듬']
# 특모듬한판
# ['특모듬', '한판']
# 소문난모듬한판
# ['듬', '한판']
# 뒷고기모듬한판
# ['듬', '한판']
# 월남쌈모듬샤브
# ['월남쌈', '듬샤브']
# 치즈듬쁙
# ['치즈', '듬쁙']
# 할매모듬
# ['듬']
# 모듬인분
# ['듬', '인분']
# 모듬쌀찐빵
# ['듬쌀', '찐빵']
# 치즈모듬감자
# ['치즈', '듬', '감자']
# 모듬회스끼다시종
# ['듬회스', '끼', '시종']
# 모듬마른안주
# ['듬']
# 모듬짬뽕
# ['듬', '짬뽕']
# 동해안모듬해산물
# ['동해안', '듬', '해산물']
# 사시미모듬
# ['사시미', '듬']
# 사사미모듬
# ['사사', '미모', '듬']
# 초밥세트모듬초밥
# ['초밥', '세트', '듬', '초밥']
# 소모듬
# ['소모', '듬']
# 돼지모듬추가
# ['돼지', '듬', '추가']
# 소모듬추가
# ['듬', '추가']
# 길모듬초밥
# ['길', '듬', '초밥']
# 반샤쿠모듬회새우야채튀김
# ['샤쿠', '듬회', '새우', '야채', '튀김']
# 반샤쿠모듬초밥
# ['샤쿠', '듬', '초밥']
# 반샤쿠모듬회인
# ['샤쿠', '듬회']
# 김치와모듬
# ['김치', '듬']
# 배가듬뿍들어간배스무디
# ['배', '듬뿍', '배', '스무디']
# 모듬정식
# ['듬', '정식']
# 모듬육류구이
# ['듬', '류구']
# 모듬곱창
# ['듬', '곱창']
# 통참백모듬탕
# ['통', '듬탕']
# 할매모듬수육
# ['듬', '수육']
# 해물모듬사리
# ['해물', '듬', '사리']
# 해산물모듬찌개
# ['해산물', '듬', '찌개']
# 모듬보쌈
# ['듬', '보쌈']
# 모듬보쌈보쌈고기추가
# ['듬', '보쌈', '보쌈', '고기', '추가']
# 진모듬
# ['진모듬']
# 모듬소세지감자튀김
# ['듬', '소세지', '감자', '튀김']
# 스시민모듬초밥
# ['스시', '민', '듬', '초밥']
# 미니모듬사시미
# ['미니모', '듬', '사시미']
# 초밥모듬
# ['초밥', '듬']
# 모듬조개탕
# ['듬', '조개', '탕']
# 모듬초밥세트
# ['듬', '초밥', '세트']
# 해물모듬구이
# ['해물', '듬', '구이']
# 바베큐오듬구이
# ['바베큐', '듬', '구이']
# 모듬스페셜
# ['듬', '스페셜']
# 치즈모듬세트
# ['치즈', '듬', '세트']
# 돈까스모듬세트
# ['돈까스', '듬', '세트']
# 연어모듬초밥
# ['연어', '듬', '초밥']
# 한우특모듬
# ['한우', '특모듬']
# 모듬순대수육
# ['듬', '수육']
# 야채모듬
# ['야채', '듬']
# 후라이드모듬감자
# ['후라이드', '듬', '감자']
# 후라이드모듬소세지
# ['후라이드', '듬', '소세지']
# 모듬삼합
# ['듬', '합']
# 멍게모듬
# ['멍게', '듬']
# 모듬치즈샐러드
# ['듬', '치즈', '샐러드']
# 마라해산물모듬
# ['해산물', '듬']
# 카오위류야채모듬추가
# ['카', '오위', '류', '채모', '듬', '추가']
# 롱샤모듬
# ['롱샤모듬']
# 돈모듬
# ['돈모듬']
# 모듬초밥메밀또는우동새우튀김
# ['듬', '초밥', '메밀', '우동', '새우', '튀김']
# 모듬사시미서더리탕새우튀김
# ['듬', '사시미', '탕', '새우', '튀김']
# 떡볶이모듬
# ['떡볶이', '듬']
# 한양모듬떡볶이
# ['듬', '떡볶이']
# 모듬구이고등어시래기찌개
# ['듬', '고등어', '시래기', '찌개']
# 모듬치즈
# ['듬', '치즈']
# 모듬젓
# ['모듬젓']
# 모듬라면
# ['모듬라']
# 듬뿍김밥
# ['듬뿍', '김밥']
# 훈제모듬
# ['훈제', '듬']
# 치즈듬뿍계란말이
# ['치즈', '듬뿍', '계란말이']
# 모듬세꼬시
# ['모듬세꼬시']
# 생와사비게살듬뿍김밥
# ['생', '와사비', '게살', '듬뿍', '김밥']
# 자몽듬뿍차
# ['자몽', '듬뿍', '차']
# 레몬듬뿍차
# ['레몬', '듬뿍', '차']
# 모듬회사시미
# ['듬', '회사', '시미']
# 홍쉐프모듬스테이크세트
# ['홍', '쉐프', '듬', '스테이크', '세트']
# 참치모듬회
# ['참치', '듬회']
# 모듬소고기쌀국수
# ['듬', '소고기', '쌀국수']
# 수제모듬튀김
# ['듬', '튀김']
# 야훠모듬
# ['야훠모듬']
# 견과모듬
# ['견과', '듬']
# 모듬햄
# ['모듬햄']
# 양곱창모듬전골
# ['곱창', '듬', '전골']
# 특본모듬스테이크
# ['특본모듬', '스테이크']
# 본모듬스테이트
# ['듬', '스테이', '트']
# 등심모듬스테이크
# ['등심', '듬', '스테이크']
# 잔치집모듬전
# ['잔치', '집', '듬전']
# 셋트모듬전식
# ['셋', '트모듬', '전식']
# 셋트모듬전식인추가
# ['셋', '트모듬', '전식', '추가']
# 특선모듬전식
# ['특선', '듬', '전식']
# 특선모듬전식인추가
# ['특선', '듬', '전식', '추가']
# 돼지머리고기모듬
# ['돼지', '머리', '기모', '듬']
# 모듬에피타이저
# ['듬', '에피타이저']
# 믿음직숯불모듬구이
# ['믿음', '직', '숯불', '듬', '구이']
# 모듬버섯추가
# ['듬', '버섯', '추가']
# 모듬찜샤브샤브
# ['듬찜', '샤브샤브']
# 제주돼지모듬
# ['돼지', '듬']
# 가마보꼬모듬어묵탕
# ['가마보꼬', '듬', '어묵', '탕']
# 모듬가스
# ['듬', '가스']
# 모듬감자치즈스틱
# ['듬', '감자', '치즈스틱']
# 모듬튀김플레이트
# ['듬', '튀김', '플레이', '트']
# 한우모듬구이정식
# ['우모', '듬', '이정식']
# 모듬안주물회
# ['듬', '안주', '물회']
# 모듬토핑
# ['모듬토핑']
# 모듬초밥튀김우동
# ['듬', '초밥', '튀김', '우동']
# 모듬야채쇠고기볶음
# ['듬', '야채', '쇠고기', '볶음']
# 그릴모듬소세지감자튀김
# ['그릴', '듬', '소세지', '감자', '튀김']
# 치즈듬뿍돈까스
# ['치즈', '듬뿍', '돈까스']
# 모듬세트대
# ['듬', '세트']
# 모듬세트중
# ['듬', '세트']
# 한우생듬심
# ['한우', '생듬심']
# 모듬홍어
# ['듬', '홍어']
# 모듬야채꼬치
# ['듬', '야채', '꼬치']
# 찰진모듬셋트
# ['듬셋트']
# 고기듬뿍덮밥
# ['듬뿍', '밥']
# 칠리커리소세지모듬
# ['칠리', '커리', '소세지', '듬']
# 모듬부대찌개치즈떡사리스팸
# ['듬', '부대찌개', '치즈', '떡', '리스', '팸']
# 크래미듬뿍김밥
# ['래미', '듬뿍', '김밥']
# 날치알듬뿍셀프주먹밥
# ['날치', '알', '듬뿍', '셀프', '주먹밥']
# 모듬프라이
# ['듬', '프라이']
# 야채듬뿍쫄면
# ['야채', '듬뿍', '쫄면']
# 갈빗살모듬
# ['갈빗살모듬']
# 수육모듬
# ['듬']
# 차돌구이부채살구이스페셜모듬샤브샤브로변경
# ['차돌', '구이', '부채살', '구이', '스페셜', '듬', '샤브샤브', '변경']
# 치즈듬뿍볶음밥
# ['치즈', '듬뿍', '볶음밥']
# 모듬직화
# ['듬', '직화']
# 바베큐모듬플래터
# ['바베큐', '듬', '플래터']
# 모듬치즈플레이트
# ['듬', '치즈', '플레이', '트']
# 제주흑돈모듬세트
# ['제주', '돈', '듬', '세트']
# 큰모듬만두
# ['듬']
# 쌀모듬찐빵
# ['쌀', '듬', '찐빵']
# 특모듬한판광어
# ['특모듬', '한판', '광어']
# 한돈모듬한판광어
# ['돈', '듬', '한판', '광어']
# 모듬한판광어
# ['듬', '한판', '광어']
# 모듬회덮밥
# ['듬', '회덮밥']
# 카이센동모듬
# ['카이센동', '듬']
# 부산어묵모듬
# ['부산', '어묵', '듬']
# 차차모듬플래터
# ['차차', '듬', '플래터']
# 모듬샤브야채
# ['듬샤브', '야채']
# 해산물모듬스페셜
# ['해산물', '듬', '스페셜']
# 더먹어라모듬튀김
# ['더', '라모', '듬', '튀김']
# 다먹어라모듬튀김
# ['라모', '듬', '튀김']
# 모듬골뱅이탕
# ['듬', '골뱅이', '탕']
# 특해물모듬물회
# ['특해물모듬', '물회']
# 순대고기모듬
# ['고기', '듬']
# 치즈듬뿍
# ['치즈', '듬뿍']
# 밤듬뿍
# ['밤', '듬뿍']
# 모듬안주
# ['듬', '안주']
# 모듬부대구이
# ['듬', '부대', '구이']
# 모듬부대
# ['듬', '부대']
# 돈까스모듬떡볶이
# ['돈까스', '듬', '떡볶이']
# 사시미모듬인
# ['사시미', '듬']
# 모듬계란말이
# ['듬', '계란말이']
# 모듬추가
# ['모듬추']
# 카레모듬덮밥
# ['카레', '듬', '밥']
# 모듬편백찜
# ['듬', '편백', '찜']
# 모듬콩콥샐러드
# ['듬콩콥', '샐러드']
# 해물모듬오뎅
# ['해물', '듬', '오뎅']
# 비원한우특선모듬
# ['비원', '한우', '특선', '듬']
# 샐러드듬뿍클럽브런치
# ['샐러드', '듬뿍', '클럽', '브런치']
# 과즙듬뿍백자몽빙수
# ['과즙', '듬뿍', '자몽', '빙수']
# 국산팥듬뿍인절미빙수
# ['국산', '팥', '듬뿍', '인절미', '빙수']
# 킹콩모듬사리세트인
# ['킹콩', '듬', '사리', '세트']
# 모듬특대
# ['듬', '특대']
# 곱창모듬
# ['곱창', '듬']
# 담소모듬
# ['담소', '듬']
# 철판모듬바베큐
# ['철판', '듬', '바베큐']
# 모듬포구이
# ['듬', '포구']
# 모듬직화볶음
# ['듬', '직화', '볶음']
# 고기듬뿍설농탕
# ['고기', '듬뿍', '설농탕']
# 특모듬과일
# ['특모듬', '과일']
# 구운모듬소시지
# ['운모', '듬', '소시지']
# 철판모듬수제소시지구이
# ['철판', '듬', '소시지', '구이']
# 소시지모듬구이
# ['소시지', '듬', '구이']
# 모듬돈가스
# ['듬', '돈가스']
# 전복모듬삼합
# ['전복', '듬', '합']
# 특선모듬꼬치종
# ['특선', '듬', '꼬치', '종']
# 모듬버섯샌드위치
# ['듬', '버섯', '샌드위치']
# 모듬사이드세트
# ['듬', '사이드', '세트']
# 모듬막회
# ['모듬막회']
# 쭈꾸미모듬전골
# ['쭈꾸미', '듬', '전골']
# 모듬된장찌개고기
# ['듬', '된장찌개', '고기']
# 모듬전무한리필
# ['듬', '무한리필']
# 가족모듬
# ['가족', '듬']
# 모듬불치즈닭
# ['듬', '불치', '닭']
# 계절별모듬전
# ['계절', '듬전']
# 모듬냉면
# ['모듬냉']
# 모듬버섯스파게티
# ['듬', '버섯', '스파게티']
# 모듬한잎
# ['듬', '잎']
# 모듬대판
# ['듬', '대판']
# 스페셜모듬초밥
# ['스페셜', '듬', '초밥']
# 모듬어묵
# ['듬', '어묵']
# 햄듬뿍샌드위치
# ['햄', '듬뿍', '샌드위치']
# 햄듬뿍샌드위치아메리카노
# ['햄', '듬뿍', '샌드위치', '아메리카노']
# 건강모듬낫또
# ['건강', '듬', '낫또']
# 모듬고르케
# ['모듬고르케']
# 돌판모듬수육
# ['돌판', '듬', '수육']
# 버섯모듬구이
# ['버섯모', '듬', '구이']
# 듬뿍참치
# ['듬뿍', '참치']
# 모듬가츠정식
# ['듬가츠', '정식']
# 특모듬사시미
# ['특모듬', '사시미']
# 모듬부위
# ['듬', '부위']
# 맛보기모듬
# ['맛보기', '듬']
# 일품모듬요리
# ['일품', '듬', '요리']
# 고릴라모듬샐러드
# ['고릴라', '듬', '샐러드']
# 새우듬뿍파스타
# ['새우', '듬뿍', '파스타']
# 고릴라모듬튀김
# ['고릴라', '듬', '튀김']
# 모듬굽다
# ['듬']
# 모듬스테이크인분추가
# ['듬', '스테이크', '분추']
# 모듬나베세트
# ['듬', '베', '세트']
# 해물모듬직화
# ['해물', '듬', '직화']
# 북촌큰모듬
# ['북촌', '듬']
# 스페샬모듬세트평일디너
# ['스페샬모듬', '세트', '평일', '디너']
# 스페샬모듬세트평일런치
# ['스페샬모듬', '세트', '평일', '런치']
# 스페셜모듬회
# ['스페셜', '듬회']
# 한우모듬스페셜
# ['우모', '듬', '스페셜']
# 김말이모듬꼬치
# ['김말이', '듬', '꼬치']
# 모듬셋트튀김
# ['듬셋트', '튀김']
# 공만모듬마른안주
# ['듬']
# 모듬순대국
# ['듬', '대국']
# 모듬오뎅탕오뎅
# ['듬', '오뎅', '탕', '오뎅']
# 모듬오뎅탕해물
# ['듬', '오뎅', '탕', '해물']
# 모듬오뎅탕우동
# ['듬', '오뎅', '탕', '우동']
# 가지의마른안주모듬
# ['가지', '듬']
# 수제모듬가스
# ['듬', '가스']
# 코스게요리모듬스페샬매운탕추가
# ['코스', '요리', '듬스페샬', '매운탕', '추가']
# 게요리모듬스페샬
# ['게', '요리', '듬스페샬']
# 모듬생천초밥
# ['듬', '생천', '초밥']
# 금일의모듬꼬치구이
# ['금일', '듬', '꼬치', '구이']
# 모듬보쌈홍어문어
# ['듬', '보쌈', '홍어', '문어']
# 모듬보쌈홍어굴
# ['듬', '보쌈', '홍어', '굴']
# 모듬보쌈문어굴
# ['듬', '보쌈', '문어', '굴']
# 돈가스모듬튀김
# ['돈가스', '듬', '튀김']
# 매운모듬수육
# ['운모', '듬', '수육']
# 매운모듬낙지수육
# ['운모', '듬', '낙지', '수육']

# %% [markdown]
# 토큰화 결과만 봐도 뭔가 이상하다는 것을 알 수 있다.
# 토크나이저가 도메인에 맞게 훈련되지 않았다는 점이 문제의 원인이라고 가정
#
# 표준데이터셋을 학습한 soynlp를 통한 토큰화를 시도해본다

# %%
# !pip install soynlp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting soynlp
#   Downloading soynlp-0.0.493-py3-none-any.whl (416 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 416.8/416.8 KB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.0.1 in /usr/local/lib/python3.8/dist-packages (from soynlp) (5.4.8)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from soynlp) (1.7.3)
# Requirement already satisfied: numpy>=1.12.1 in /usr/local/lib/python3.8/dist-packages (from soynlp) (1.21.6)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.8/dist-packages (from soynlp) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.20.0->soynlp) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.20.0->soynlp) (3.1.0)
# Installing collected packages: soynlp
# Successfully installed soynlp-0.0.493

# %%
corpus = pd.read_csv('/content/Kor_standard_menu_clean.csv')

# %%
corpus
# Out:
#       Unnamed: 0              title large_category category
# 0              0        케이크 너트 브라우니        빵 및 과자류      케이크
# 1              1     케이크 녹차바스크치즈케이크        빵 및 과자류      케이크
# 2              2      케이크 녹차티라미수케이크        빵 및 과자류      케이크
# 3              3       케이크 뉴욕 치즈케이크        빵 및 과자류      케이크
# 4              4  케이크 뉴욕슈치즈케이크 (조각)        빵 및 과자류      케이크
# ...          ...                ...            ...      ...
# 8298        8298              청포묵무침         생채·무침류    청포묵무침
# 8299        8299             치커리겉절이         생채·무침류   치커리겉절이
# 8300        8300          파래무침 파래 무         생채·무침류     파래무침
# 8301        8301               짜장소스        장류, 양념류     짜장소스
# 8302        8302               카레소스        장류, 양념류     카레소스
#
# [8303 rows x 4 columns]

# %%
corpus = corpus['title']

# %%
corpus = corpus.replace(r'\([^)]*\)','',regex=True)

# %%
corpus = corpus.drop_duplicates()

# %%
from soynlp.tokenizer import MaxScoreTokenizer, RegexTokenizer

tokenizer = RegexTokenizer() ## Regex 기준 토크나이저, 띄어쓰기가 있거나 이어지는 단어가 한국어가 아닐 경우 토큰화

corpus_list = []

for word in corpus:
  corpus_list.append(tokenizer.tokenize(word))

# %%
corpus_list

# %%
corpus_dict = {}

for tokens in corpus_list:
  for token in tokens:
    corpus_dict[token] = 1.0

    ## MaxScoreTokenizer에 사용할 커스텀 사전, 점수를 넣을 경우 해당 단어를 토큰으로 분리하는 가중치를 지정
    ## 서울대학교 라는 단어가 있는데, 서울 :1 대학교 : 1 서울대학교 : 1 이처럼 점수가 같을 경우
    ## 단어가 긴 서울대학교를 우선으로 지정해준다

# %%
corpus_dict

# %%
tokenizer = MaxScoreTokenizer(scores=corpus_dict) ## 위에서 만든 사전을 점수 계산으로 지정

# %%
from tqdm import tqdm

menu_list = [tokenizer.tokenize(word) for word in tqdm(menu_list)]
# Out:
#   0%|          | 0/51437 [00:00<?, ?it/s]
#   9%|▊         | 4436/51437 [00:00<00:01, 44347.99it/s]
#  17%|█▋        | 8871/51437 [00:00<00:01, 40596.25it/s]
#  25%|██▌       | 12952/51437 [00:00<00:00, 38609.29it/s]
#  33%|███▎      | 16828/51437 [00:00<00:00, 37230.33it/s]
#  40%|███▉      | 20560/51437 [00:00<00:00, 35254.32it/s]
#  47%|████▋     | 24098/51437 [00:00<00:00, 34458.33it/s]
#  54%|█████▎    | 27550/51437 [00:00<00:00, 32786.35it/s]
#  60%|█████▉    | 30839/51437 [00:00<00:00, 32722.54it/s]
#  66%|██████▋   | 34118/51437 [00:01<00:00, 24148.79it/s]
#  72%|███████▏  | 37042/51437 [00:01<00:00, 25351.09it/s]
#  78%|███████▊  | 40362/51437 [00:01<00:00, 27330.82it/s]
#  84%|████████▍ | 43446/51437 [00:01<00:00, 28258.90it/s]
#  91%|█████████ | 46806/51437 [00:01<00:00, 29724.90it/s]
# 100%|██████████| 51437/51437 [00:01<00:00, 30892.79it/s]

# %%
from collections import Counter

df['tokens'] = menu_list
# Counter 객체는 리스트요소의 값과 요소의 갯수를 카운트 하여 저장하고 있습니다.
# 카운터 객체는 .update 메소드로 계속 업데이트 가능합니다.
word_counts = Counter()

# 토큰화된 각 리뷰 리스트를 카운터 객체에 업데이트 합니다. 
df['tokens'].apply(lambda x: word_counts.update(x))

# 가장 많이 존재하는 단어 순으로 10개를 나열합니다
word_counts.most_common(10)
# Out:
# [('치즈', 1431),
#  ('세트', 1372),
#  ('치킨', 1358),
#  ('새우', 906),
#  ('모듬', 644),
#  ('볶음', 590),
#  ('추가', 570),
#  ('라떼', 538),
#  ('양념', 536),
#  ('샐러드', 529)]

# %%
## 가장 적게 존재하는 단어 순으로 정렬합니다. 10개만 나타내는 경우
word_counts.most_common()[:-10:-1]
# Out:
# [('좌종당계', 1),
#  ('비풍당', 1),
#  ('철판통후추', 1),
#  ('자연송이죽생', 1),
#  ('설화샥스핀', 1),
#  ('샥스핀홀', 1),
#  ('불도장정식', 1),
#  ('매운꼬리', 1),
#  ('대운탕', 1)]

# %%
token_list = word_counts.keys()

# %%
len_1_tokens = []

for token in token_list:
  if len(token) <= 1:
    len_1_tokens.append(token)

# %%
len(token_list)
# Out:
# 24689

# %%
len(len_1_tokens)
# Out:
# 512

# %%
for i, token_list in enumerate(df['tokens']):
  for token in token_list:
    if '듬' in token:
      print(df['menu'].iloc[i])
      print(token_list)
# Out:
# 모듬회
# ['모듬회']
# 모듬튀김
# ['모듬튀김']
# 건어물모듬
# ['건어물모듬']
# 모듬
# ['모듬']
# 모듬양장피
# ['모듬', '양장피']
# 조개모듬구이
# ['조개모듬구이']
# 모듬회스페셜
# ['모듬회스페셜']
# 삼영모듬회스페셜
# ['삼영모듬회스페셜']
# 삼영해산물모듬스페셜
# ['삼영해산물모듬스페셜']
# 자연산모듬회
# ['자연산모듬회']
# 모듬해물
# ['모듬해물']
# 해물모듬
# ['해물모듬']
# 해물모듬물회
# ['해물모듬', '물회']
# 살고기모듬수육
# ['살고기모듬', '수육']
# 모듬수육
# ['모듬', '수육']
# 모듬전
# ['모듬전']
# 모듬회코스
# ['모듬회코스']
# 한우모듬
# ['한우모듬']
# 모듬양곱창
# ['모듬양곱창']
# 모듬스테이크
# ['모듬', '스테이크']
# 모듬전골
# ['모듬전골']
# 고기듬뿍김치찌개
# ['고기듬뿍', '김치찌개']
# 해산물모듬
# ['해산물모듬']
# 모듬양념구이
# ['모듬양념구이']
# 연어모듬회
# ['연어모듬회']
# 특모듬
# ['특모듬']
# 고급어종모듬
# ['고급어종모듬']
# 모듬조개전복
# ['모듬조개전복']
# 모듬조개
# ['모듬조개']
# 생선모듬초밥
# ['생선모듬', '초밥']
# 모듬스페샬
# ['모듬스페샬']
# 고기듬북김치찌개
# ['고기듬북', '김치찌개']
# 모듬오뎅탕
# ['모듬오뎅탕']
# 모듬감자튀김
# ['모듬', '감자튀김']
# 순대모듬
# ['순대', '모듬']
# 모듬국밥
# ['모듬', '국밥']
# 모듬생선구이
# ['모듬생선구이']
# 모듬생선회삿뽀로
# ['모듬생선회삿뽀로']
# 모듬생선회오타루
# ['모듬생선회오타루']
# 모듬생선회오도리
# ['모듬생선회오도리']
# 모듬초밥개
# ['모듬', '초밥', '개']
# 모듬꼬치세트
# ['모듬꼬치세트']
# 모듬후라이
# ['모듬후라이']
# 모듬회대
# ['모듬회대']
# 모듬회중
# ['모듬회중']
# 모듬회소
# ['모듬회소']
# 돼지고기듬뿍김치찜
# ['돼지고기', '듬뿍', '김치찜']
# 모듬막창구이
# ['모듬', '막창구이']
# 따로모듬국밥
# ['따로모듬', '국밥']
# 모듬구이
# ['모듬구이']
# 일돈특수모듬
# ['일돈특수모듬']
# 일돈양념모듬
# ['일돈양념모듬']
# 특수모듬양념모듬
# ['특수모듬양념모듬']
# 양식모듬회
# ['양식모듬회']
# 모듬물회
# ['모듬', '물회']
# 모듬만두
# ['모듬', '만두']
# 모듬세트
# ['모듬세트']
# 모듬곰탕
# ['모듬', '곰탕']
# 참다랑어모듬
# ['참다랑어모듬']
# 참치모듬초밥
# ['참치모듬', '초밥']
# 참치모듬눈다랑어부위
# ['참치모듬눈다랑어부위']
# 모듬초밥
# ['모듬', '초밥']
# 오늘의모듬초밥
# ['오늘의모듬', '초밥']
# 특모듬국밥
# ['특모듬', '국밥']
# 고구마치즈스틱모듬감자
# ['고구마', '치즈스틱', '모듬', '감자']
# 모듬해물짬뽕
# ['모듬해물', '짬뽕']
# 매듬해불짬뽕밥
# ['매듬해불', '짬뽕밥']
# 해삼모듬
# ['해삼모듬']
# 고래모듬
# ['고래모듬']
# 모듬회특
# ['모듬회특']
# 자연산모듬회특
# ['자연산모듬회특']
# 예담모듬세트
# ['예담모듬세트']
# 모듬가라아게
# ['모듬가라아게']
# 모듬해산물
# ['모듬해산물']
# 특모듬보쌈
# ['특모듬보쌈']
# 모듬새우튀김
# ['모듬새우튀김']
# 모듬생선회
# ['모듬생선회']
# 따로모듬
# ['따로모듬']
# 모듬수제돈까스
# ['모듬수제돈까스']
# 모듬사시미
# ['모듬사시미']
# 모듬까스
# ['모듬까스']
# 제주특모듬
# ['제주특모듬']
# 모듬버섯
# ['모듬버섯']
# 덕포모듬회
# ['덕포모듬회']
# 튀김모듬
# ['튀김모듬']
# 특모듬회
# ['특모듬회']
# 삼겹파티모듬
# ['삼겹파티모듬']
# 버섯모듬
# ['버섯모듬']
# 모듬소세지
# ['모듬소세지']
# 모듬김밥
# ['모듬', '김밥']
# 신선모듬사시미
# ['신선모듬사시미']
# 해물모듬철판구이
# ['해물모듬철판구이']
# 용궁해물모듬
# ['용궁해물모듬']
# 기본어종모듬
# ['기본어종모듬']
# 참돔어종모듬
# ['참돔어종모듬']
# 돌돔어종모듬
# ['돌돔어종모듬']
# 양갈비모듬
# ['양갈비모듬']
# 등갈비모듬
# ['등갈비모듬']
# 계절모듬회
# ['계절모듬회']
# 모듬해물된장죽
# ['모듬해물된장죽']
# 모듬해물죽
# ['모듬해물죽']
# 모듬포안주
# ['모듬포안주']
# 생고기모듬
# ['생고기모듬']
# 고급모듬회
# ['고급모듬회']
# 모듬순대
# ['모듬', '순대']
# 딤섬모듬
# ['딤섬모듬']
# 모듬한판
# ['모듬한판']
# 해물모듬짬뽕
# ['해물모듬', '짬뽕']
# 특수부위모듬
# ['특수부위모듬']
# 흑돼지모듬
# ['흑돼지모듬']
# 순두부모듬전골
# ['순두부모듬전골']
# 생등심돈까스모듬
# ['생등심돈까스모듬']
# 모듬활어회
# ['모듬활어회']
# 모듬감자
# ['모듬', '감자']
# 스페셜모듬튀김
# ['스페셜모듬튀김']
# 오징어모듬회
# ['오징어모듬회']
# 생연어모듬회
# ['생연어모듬회']
# 모듬까스안주
# ['모듬까스안주']
# 모듬어묵탕
# ['모듬', '어묵탕']
# 모듬타파스
# ['모듬타파스']
# 모듬술국
# ['모듬술국']
# 명품모듬전
# ['명품모듬전']
# 돼지모듬
# ['돼지모듬']
# 생선구이모듬
# ['생선구이모듬']
# 모듬해물사시미
# ['모듬해물사시미']
# 모듬꼬치
# ['모듬꼬치']
# 불꽃모듬
# ['불꽃모듬']
# 피자주문시치즈듬뿍
# ['피자', '주문시', '치즈', '듬뿍']
# 제주모듬
# ['제주모듬']
# 과일모듬
# ['과일', '모듬']
# 돼지특수모듬
# ['돼지특수모듬']
# 돼지특수모듬추가
# ['돼지특수모듬추가']
# 혼마구로모듬
# ['혼마구로모듬']
# 참치회모듬
# ['참치회모듬']
# 모듬철판볶음밥
# ['모듬철판', '볶음밥']
# 츠키지풍모듬초밥
# ['츠키지풍모듬', '초밥']
# 한우특수모듬
# ['한우특수모듬']
# 모듬야채
# ['모듬야채']
# 제주모듬한판
# ['제주모듬한판']
# 모듬치즈플래터
# ['모듬', '치즈', '플래터']
# 기타모듬
# ['기타모듬']
# 가타추가류모듬
# ['가타추가류모듬']
# 실속모듬세트
# ['실속모듬세트']
# 고급뱃살모듬세트
# ['고급뱃살모듬세트']
# 인모듬
# ['인모듬']
# 수제모듬소세지
# ['수제모듬소세지']
# 모듬소시지
# ['모듬', '소시지']
# 모듬볶음밥
# ['모듬', '볶음밥']
# 그릴모듬떡갈비
# ['그릴모듬', '떡갈비']
# 사계절철별미모듬오뎅탕
# ['사계절철별미모듬오뎅', '탕']
# 조개모듬
# ['조개모듬']
# 장어모듬
# ['장어모듬']
# 모듬찜류
# ['모듬찜류']
# 모듬튀김류
# ['모듬튀김류']
# 모듬피쉬볼
# ['모듬피쉬볼']
# 양파듬뿍돈까스
# ['양파듬뿍돈까스']
# 치즈듬뿍감자튀김
# ['치즈', '듬뿍', '감자튀김']
# 양파듬뿍카츠
# ['양파듬뿍카츠']
# 와규모듬추가
# ['와규모듬추가']
# 모듬오뎅
# ['모듬오뎅']
# 모듬꼬지
# ['모듬꼬지']
# 모듬조개구이
# ['모듬', '조개구이']
# 모듬한접시
# ['모듬한접시']
# 모듬고기
# ['모듬고기']
# 계절모듬사시미
# ['계절모듬사시미']
# 모듬과일
# ['모듬', '과일']
# 모듬소시지구이
# ['모듬', '소시지', '구이']
# 모듬사시미벤또
# ['모듬사시미벤또']
# 오덕모듬돈까스
# ['오덕모듬돈까스']
# 참치모듬
# ['참치모듬']
# 유기농종모듬현미선물세트
# ['유기농종모듬현미선물', '세트']
# 모듬꼬마김밥
# ['모듬꼬마', '김밥']
# 모듬꼬지구이종
# ['모듬꼬지구이종']
# 모듬고로케
# ['모듬고로케']
# 모듬생고기
# ['모듬생고기']
# 모듬어묵핫바
# ['모듬어묵핫바']
# 남도모듬
# ['남도모듬']
# 갈비특수부위모듬
# ['갈비특수부위모듬']
# 닭모듬꼬치종
# ['닭모듬꼬치종']
# 모듬소세지웨지감자
# ['모듬소세지웨지', '감자']
# 듬뿍골뱅이무침
# ['듬뿍', '골뱅이무침']
# 모듬양곱찰
# ['모듬양곱찰']
# 모듬조개찜
# ['모듬조개찜']
# 모듬회초장인
# ['모듬회초장인']
# 조개구이모듬회해물라면치즈
# ['조개구이', '모듬회해물', '라면', '치즈']
# 모듬회해물탕
# ['모듬회', '해물탕']
# 모듬회곰장어
# ['모듬회곰장어']
# 모듬회물회매운탕
# ['모듬회', '물회', '매운탕']
# 모듬회새우구이
# ['모듬회', '새우구이']
# 스페셜참치모듬회
# ['스페셜참치모듬회']
# 쿄우스페셜모듬회
# ['쿄우스페셜모듬회']
# 와규모듬구이
# ['와규모듬구이']
# 모듬냉채
# ['모듬', '냉채']
# 생선모듬찜
# ['생선모듬찜']
# 태국식모듬튀김
# ['태국식모듬튀김']
# 해물듬뿍부추전
# ['해물듬뿍', '부추전']
# 치즈듬뿍콤비네이션
# ['치즈', '듬뿍콤비네이션']
# 차즈듬뿍콤비네이션
# ['차즈듬뿍콤비네이션']
# 모듬치킨
# ['모듬치킨']
# 모듬해물탕
# ['모듬', '해물탕']
# 오덕모듬까스
# ['오덕모듬까스']
# 특수부위생고기모듬
# ['특수부위생고기모듬']
# 모듬새우초밥
# ['모듬새우', '초밥']
# 참치뱃살모듬
# ['참치뱃살모듬']
# 모듬쿠시카츠
# ['모듬쿠시카츠']
# 해물모듬소
# ['해물모듬소']
# 모듬치즈과일
# ['모듬', '치즈', '과일']
# 뚱대삼이모듬
# ['뚱대삼이모듬']
# 한돈모듬한판
# ['한돈모듬한판']
# 야채모듬구이
# ['야채모듬구이']
# 바나나듬뿍
# ['바나나듬뿍']
# 스페샬모듬
# ['스페샬모듬']
# 생모듬한판
# ['생모듬한판']
# 모듬손만두
# ['모듬손', '만두']
# 활어모듬회
# ['활어모듬회']
# 젠닌모듬오뎅탕
# ['젠닌모듬오뎅탕']
# 대게모듬꼬치
# ['대게모듬꼬치']
# 모듬생선
# ['모듬생선']
# 모듬사시미정식
# ['모듬사시미정식']
# 한우생모듬세트
# ['한우생모듬세트']
# 모듬고노와다
# ['모듬고노와다']
# 소미모듬세트
# ['소미모듬세트']
# 모듬스팸후라이
# ['모듬스팸후라이']
# 꾼모듬튀김
# ['꾼모듬튀김']
# 꾼모듬사시미
# ['꾼모듬사시미']
# 꾼모듬초밥
# ['꾼모듬', '초밥']
# 모듬튀김우동
# ['모듬튀김', '우동']
# 모듬포테이토
# ['모듬포테이토']
# 모듬수육추가
# ['모듬', '수육', '추가']
# 모듬햄짜글이
# ['모듬햄짜글이']
# 모듬카츠정식
# ['모듬카츠정식']
# 순대모듬전골
# ['순대', '모듬전골']
# 활랍스터모듬사시미
# ['활랍스터모듬사시미']
# 스페셜활랍스터모듬사미
# ['스페셜활랍스터모듬사', '미']
# 키이로모듬회
# ['키이로모듬회']
# 깐풍모듬해산물
# ['깐풍모듬해산물']
# 모듬짬뽕전골
# ['모듬', '짬뽕', '전골']
# 청경채모듬버섯볶음
# ['청경채모듬', '버섯볶음']
# 모듬치킨세트
# ['모듬치킨세트']
# 산구모듬
# ['산구모듬']
# 한상가득모듬
# ['한상가득모듬']
# 특별한상가득모듬
# ['특별한상가득모듬']
# 생선모듬구이
# ['생선모듬구이']
# 왕모듬물회
# ['왕모듬', '물회']
# 모듬사시미종
# ['모듬사시미종']
# 해물모듬숙회
# ['해물모듬', '숙회']
# 인혼술모듬
# ['인혼술모듬']
# 고니듬뿍알탕
# ['고니듬뿍', '알탕']
# 생크림모듬
# ['생크림모듬']
# 무스모듬
# ['무스모듬']
# 해물모듬중
# ['해물모듬중']
# 해물모듬대
# ['해물모듬대']
# 바닷가모듬회회추가시
# ['바닷가모듬회회추가시']
# 돼지듬뿍김치찌개
# ['돼지듬뿍', '김치찌개']
# 스페셜모듬
# ['스페셜모듬']
# 계양간모듬
# ['계양간모듬']
# 모듬쏘세지
# ['모듬쏘세지']
# 각종모듬튀김
# ['각종모듬튀김']
# 에그듬뿍샌드위치
# ['에그듬뿍', '샌드위치']
# 모듬코스
# ['모듬코스']
# 모듬플레터
# ['모듬플레터']
# 모듬타파스종
# ['모듬타파스종']
# 독일모듬소세지
# ['독일모듬소세지']
# 모듬볼
# ['모듬볼']
# 제철모듬사시미
# ['제철모듬사시미']
# 모듬셋트
# ['모듬셋트']
# 듬뿍야채쫄쫄면
# ['듬뿍야채쫄', '쫄면']
# 평범해서맛있는모듬
# ['평범해서맛있는모듬']
# 선장해물모듬
# ['선장해물모듬']
# 모듬브르스게타
# ['모듬브르스게타']
# 새우모듬초밥
# ['새우모듬', '초밥']
# 더랭햄그릴모듬
# ['더랭햄그릴모듬']
# 모듬눈꽃감자튀김
# ['모듬눈꽃', '감자튀김']
# 일반모듬
# ['일반모듬']
# 수제모듬어묵
# ['수제모듬어묵']
# 간편한국탕용모듬어묵
# ['간편한국탕용모듬어묵']
# 모듬튀밥세트
# ['모듬튀밥세트']
# 버섯야채모듬사리
# ['버섯야채모듬사리']
# 모듬야채볶음
# ['모듬야채볶음']
# 모듬버섯볶음
# ['모듬', '버섯볶음']
# 특모듬초밥
# ['특모듬', '초밥']
# 고급한우모듬
# ['고급한우모듬']
# 모듬구이스페셜
# ['모듬구이스페셜']
# 편육모듬
# ['편육모듬']
# 모듬중
# ['모듬중']
# 모듬대
# ['모듬대']
# 양곱창모듬
# ['양곱창모듬']
# 한우명품모듬
# ['한우명품모듬']
# 싱싱모듬회
# ['싱싱모듬회']
# 새우모듬튀김
# ['새우모듬튀김']
# 모듬돈까스
# ['모듬돈까스']
# 모듬떡볶이
# ['모듬', '떡볶이']
# 특수모듬
# ['특수모듬']
# 모듬스페셜참치랍스타
# ['모듬스페셜참치랍스타']
# 생딸기듬뿍우유생크림케이크
# ['생딸기듬뿍', '우유', '생크림', '케이크']
# 블루베리요거트듬뿍케이크
# ['블루베리요거트듬뿍', '케이크']
# 촉촉한블루베리듬뿍쉬폰
# ['촉촉한블루베리듬뿍쉬', '폰']
# 모듬개
# ['모듬개']
# 치즈듬뿍피자
# ['치즈', '듬뿍', '피자']
# 어묵모듬세트
# ['어묵모듬세트']
# 전골야채모듬
# ['전골야채모듬']
# 생선모듬
# ['생선모듬']
# 마늘듬뿍닭볶음탕
# ['마늘듬뿍', '닭볶음탕']
# 알짜모듬세트
# ['알짜모듬세트']
# 모듬건어물
# ['모듬건어물']
# 모듬사시미코스인
# ['모듬사시미코스인']
# 모듬나초
# ['모듬나초']
# 모듬리필참치
# ['모듬리필참치']
# 왕새우모듬튀김
# ['왕새우모듬튀김']
# 딸기듬뿍와플
# ['딸기듬뿍', '와플']
# 종모듬꼬치
# ['종모듬꼬치']
# 제주흑돼지부위별모듬
# ['제주흑돼지부위별모듬']
# 모듬바베큐
# ['모듬바베큐']
# 무듬만두
# ['무듬', '만두']
# 철판모듬소세지
# ['철판모듬소세지']
# 계절모듬과일
# ['계절모듬', '과일']
# 번모듬
# ['번모듬']
# 제철과일듬뿍에이드
# ['제철', '과일', '듬뿍', '에이드']
# 노상모듬쌀국수
# ['노상모듬', '쌀국수']
# 매운해장모듬쌀국수
# ['매운해장모듬', '쌀국수']
# 퐁당모듬떡볶이
# ['퐁당모듬', '떡볶이']
# 모듬포
# ['모듬포']
# 모듬전골뱅이
# ['모듬전골뱅이']
# 모듬전오징어숙회
# ['모듬전오징어', '숙회']
# 한돈생고기모듬
# ['한돈생고기모듬']
# 찹쌀모듬순대
# ['찹쌀모듬', '순대']
# 해초모듬회덮밥
# ['해초모듬', '회덮밥']
# 모듬내장
# ['모듬내장']
# 모듬특
# ['모듬특']
# 통낙지모듬해물쟁반자장면
# ['통낙지모듬해물쟁반', '자장면']
# 모듬버섯덮밥
# ['모듬버섯', '덮밥']
# 모듬해물누룽지탕
# ['모듬해물', '누룽지', '탕']
# 철판모듬해물팔보채
# ['철판모듬해물', '팔보채']
# 모듬한우탕
# ['모듬한우탕']
# 모듬해물찜
# ['모듬', '해물찜']
# 돼지부속모듬
# ['돼지부속모듬']
# 실속모듬
# ['실속모듬']
# 모듬사리
# ['모듬사리']
# 모듬회무침
# ['모듬', '회무침']
# 해산물모듬회
# ['해산물모듬회']
# 모듬생선포장
# ['모듬생선포장']
# 한우스페셜모듬
# ['한우스페셜모듬']
# 마른안주모듬
# ['마른안주모듬']
# 몸보신모듬세트
# ['몸보신모듬세트']
# 모듬버섯회
# ['모듬버섯회']
# 돈특수모듬
# ['돈특수모듬']
# 모듬순대한접시
# ['모듬', '순대', '한접시']
# 직화쭈꾸미모듬안주
# ['직화쭈꾸미모듬안주']
# 모듬참치회한접시
# ['모듬참치회한접시']
# 잔치모듬전
# ['잔치모듬전']
# 모듬생선초밥
# ['모듬생선', '초밥']
# 청정모듬순대
# ['청정모듬', '순대']
# 반곡역한우특수부위모듬
# ['반곡역한우특수부위모', '듬']
# 스페셜모듬치즈
# ['스페셜모듬', '치즈']
# 산지직송해산물모듬
# ['산지직송해산물모듬']
# 모듬생선조림
# ['모듬생선조림']
# 한우모듬구이
# ['한우모듬구이']
# 유버모듬맛감자튀김
# ['유버모듬맛', '감자튀김']
# 모듬감튀
# ['모듬감튀']
# 모듬소세지감튀
# ['모듬소세지감튀']
# 한우모듬자연산송이버섯세트
# ['한우모듬자연산송이버', '섯세트']
# 명품모듬자연산송이버섯세트
# ['명품모듬자연산송이버', '섯세트']
# 문어모듬보쌈
# ['문어모듬보쌈']
# 모듬보족
# ['모듬보족']
# 모듬닭갈비
# ['모듬닭갈비']
# 모듬뱅이
# ['모듬뱅이']
# 흙마늘모듬구이
# ['흙마늘모듬구이']
# 치즈모듬감자튀김
# ['치즈', '모듬', '감자튀김']
# 모듬해삼
# ['모듬해삼']
# 제우스모듬
# ['제우스모듬']
# 한우모듬삼창
# ['한우모듬삼창']
# 모듬쌀찐빵개
# ['모듬쌀찐빵개']
# 모듬수육소
# ['모듬', '수육', '소']
# 모듬수육대
# ['모듬', '수육', '대']
# 모듬전골중
# ['모듬전골중']
# 모듬전골대
# ['모듬전골대']
# 치즈듬뿍순꿀꽃
# ['치즈', '듬뿍순꿀꽃']
# 밤이듬뿍맘모스
# ['밤이듬뿍맘모스']
# 하트를듬뿍담은쇼콜라스퀘어
# ['하트를듬뿍담은쇼콜라', '스퀘어']
# 모듬바베큐플레이트
# ['모듬바베큐플레이트']
# 즉석모듬떡볶이
# ['즉석모듬', '떡볶이']
# 명태회모듬수육
# ['명태회모듬', '수육']
# 모듬소세지구이
# ['모듬소세지구이']
# 해물듬뿍파전
# ['해물듬뿍', '파전']
# 생선삼모듬
# ['생선삼모듬']
# 전하면모듬전
# ['전하면모듬전']
# 모듬닭사리
# ['모듬닭사리']
# 고기듬뿍카레라이스
# ['고기듬뿍', '카레라이스']
# 모듬삼창
# ['모듬삼창']
# 매니아모듬튀김
# ['매니아모듬튀김']
# 모듬어묵탕우동사리
# ['모듬', '어묵탕', '우동', '사리']
# 태권모듬떡볶이세트
# ['태권모듬', '떡볶이', '세트']
# 모듬종소스
# ['모듬종', '소스']
# 모듬회큰형
# ['모듬회큰형']
# 모듬회작은형
# ['모듬회작은형']
# 모듬회막내
# ['모듬회막내']
# 모듬회세트
# ['모듬회세트']
# 전복모듬물회
# ['전복모듬', '물회']
# 이베리코모듬
# ['이베리코모듬']
# 모듬해물한판
# ['모듬해물한판']
# 모듬부대찌개
# ['모듬', '부대찌개']
# 꽃돼지모듬
# ['꽃돼지모듬']
# 모듬라볶이
# ['모듬', '라볶이']
# 모듬꼬치구이
# ['모듬', '꼬치구이']
# 쇠고기듬뿍볶음밥음료
# ['쇠고기듬뿍', '볶음밥', '음료']
# 쇠고기듬뿍팬볶이
# ['쇠고기듬뿍팬볶이']
# 세트메뉴모듬
# ['세트메뉴모듬']
# 크런치모듬튀김
# ['크런치모듬튀김']
# 고기듬뿍물쫄면
# ['고기듬뿍물', '쫄면']
# 미돈모듬안주
# ['미돈모듬안주']
# 특수부속모듬
# ['특수부속모듬']
# 알모듬
# ['알모듬']
# 모듬순대대
# ['모듬', '순대', '대']
# 모듬순대중
# ['모듬', '순대', '중']
# 모듬샤브샤브칼국수
# ['모듬', '샤브샤브', '칼국수']
# 모듬만두비빔만두
# ['모듬', '만두', '비빔', '만두']
# 모듬튀김세트
# ['모듬튀김세트']
# 듬뿍콘버터
# ['듬뿍콘버터']
# 모듬생선회대
# ['모듬생선회대']
# 모듬생선구이돌솥밥
# ['모듬생선구이돌솥밥']
# 흑염소생양념모듬숯불구이
# ['흑염소생양념모듬숯불', '구이']
# 흑염소생모듬숯불구이
# ['흑염소생모듬숯불구이']
# 살치살갈비살등심모듬인셋트
# ['살치살갈비살등심모듬', '인셋트']
# 등심모듬
# ['등심모듬']
# 모듬전육전동태전굴전동그랑땡호
# ['모듬전육전', '동태전', '굴전', '동그랑땡호']
# 가마보꼬모듬오뎅탕
# ['가마보꼬모듬오뎅탕']
# 번돈까스모듬소세지
# ['번돈까스모듬소세지']
# 모듬튀김한판
# ['모듬튀김한판']
# 생크림듬뿍스콘
# ['생크림듬뿍', '스콘']
# 치즈듬뿍떡볶이
# ['치즈', '듬뿍', '떡볶이']
# 미니모듬회
# ['미니모듬회']
# 모듬덴뿌라
# ['모듬덴뿌라']
# 마늘빵모듬
# ['마늘빵', '모듬']
# 참치와활어모듬
# ['참치와활어모듬']
# 활어모듬
# ['활어모듬']
# 참치모듬사시미
# ['참치모듬사시미']
# 활어모듬사시미
# ['활어모듬사시미']
# 모듬전식
# ['모듬전식']
# 세트모듬전식
# ['세트모듬전식']
# 고기모듬
# ['고기모듬']
# 알뜰모듬한상소
# ['알뜰모듬한상소']
# 푸짐모듬한상소
# ['푸짐모듬한상소']
# 항정가브리갈매기특수모듬
# ['항정가브리갈매기특수', '모듬']
# 고기듬뿍꿀갈비비빔밥된장찌개
# ['고기듬뿍꿀갈비', '비빔밥', '된장찌개']
# 고기듬뿍매운꿀갈비비빔밥된장찌개
# ['고기듬뿍매운꿀갈비', '비빔밥', '된장찌개']
# 한우암소모듬
# ['한우암소모듬']
# 특선모듬
# ['특선모듬']
# 특선모듬세트
# ['특선모듬세트']
# 새우듬뿍멘보샤
# ['새우듬뿍', '멘보샤']
# 닭뽁이모듬사리
# ['닭뽁이모듬사리']
# 까뽁이모듬사리
# ['까뽁이모듬사리']
# 크림뽁이모듬사리
# ['크림뽁이모듬사리']
# 치즈닭뽁이모듬사리
# ['치즈', '닭뽁이모듬사리']
# 알마니닭뽁이모듬사리
# ['알마니닭뽁이모듬사리']
# 명품특수모듬
# ['명품특수모듬']
# 소고기모듬구이
# ['소고기모듬구이']
# 곱창모듬구이
# ['곱창모듬구이']
# 특양모듬구이
# ['특양모듬구이']
# 허니모듬포테이토
# ['허니모듬포테이토']
# 돈육모듬
# ['돈육모듬']
# 치킨모듬세트
# ['치킨모듬세트']
# 모듬족발
# ['모듬', '족발']
# 꾼모듬요리
# ['꾼모듬요리']
# 모듬곱창볶음
# ['모듬', '곱창볶음']
# 모듬꼬치종
# ['모듬꼬치종']
# 쌀찐빵모듬한상자
# ['쌀찐빵모듬한상자']
# 뒷고기모듬
# ['뒷고기모듬']
# 생모듬
# ['생모듬']
# 모듬치즈라볶이
# ['모듬', '치즈', '라볶이']
# 모듬수육전골
# ['모듬', '수육', '전골']
# 베이컨모듬구이
# ['베이컨모듬구이']
# 내장모듬
# ['내장모듬']
# 특모듬한판
# ['특모듬한판']
# 소문난모듬한판
# ['소문난모듬한판']
# 뒷고기모듬한판
# ['뒷고기모듬한판']
# 월남쌈모듬샤브
# ['월남쌈', '모듬샤브']
# 치즈듬쁙
# ['치즈', '듬쁙']
# 할매모듬
# ['할매모듬']
# 모듬인분
# ['모듬인분']
# 모듬쌀찐빵
# ['모듬쌀찐빵']
# 치즈모듬감자
# ['치즈', '모듬', '감자']
# 모듬회스끼다시종
# ['모듬회스끼다시종']
# 모듬마른안주
# ['모듬마른안주']
# 모듬짬뽕
# ['모듬', '짬뽕']
# 동해안모듬해산물
# ['동해안모듬해산물']
# 사시미모듬
# ['사시미모듬']
# 사사미모듬
# ['사사미모듬']
# 초밥세트모듬초밥
# ['초밥', '세트모듬', '초밥']
# 소모듬
# ['소모듬']
# 돼지모듬추가
# ['돼지모듬추가']
# 소모듬추가
# ['소모듬추가']
# 길모듬초밥
# ['길모듬', '초밥']
# 반샤쿠모듬회새우야채튀김
# ['반샤쿠모듬회새우야채', '튀김']
# 반샤쿠모듬초밥
# ['반샤쿠모듬', '초밥']
# 반샤쿠모듬회인
# ['반샤쿠모듬회인']
# 김치와모듬
# ['김치와모듬']
# 배가듬뿍들어간배스무디
# ['배가듬뿍들어간배', '스무디']
# 모듬정식
# ['모듬정식']
# 모듬육류구이
# ['모듬육류구이']
# 모듬곱창
# ['모듬곱창']
# 통참백모듬탕
# ['통참백모듬탕']
# 할매모듬수육
# ['할매모듬', '수육']
# 해물모듬사리
# ['해물모듬사리']
# 해산물모듬찌개
# ['해산물모듬찌개']
# 모듬보쌈
# ['모듬보쌈']
# 모듬보쌈보쌈고기추가
# ['모듬보쌈보쌈고기추가']
# 진모듬
# ['진모듬']
# 모듬소세지감자튀김
# ['모듬소세지', '감자튀김']
# 스시민모듬초밥
# ['스시민모듬', '초밥']
# 미니모듬사시미
# ['미니모듬사시미']
# 초밥모듬
# ['초밥', '모듬']
# 모듬조개탕
# ['모듬조개탕']
# 모듬초밥세트
# ['모듬', '초밥', '세트']
# 해물모듬구이
# ['해물모듬구이']
# 바베큐오듬구이
# ['바베큐오듬구이']
# 모듬스페셜
# ['모듬스페셜']
# 치즈모듬세트
# ['치즈', '모듬세트']
# 돈까스모듬세트
# ['돈까스모듬세트']
# 연어모듬초밥
# ['연어모듬', '초밥']
# 한우특모듬
# ['한우특모듬']
# 모듬순대수육
# ['모듬', '순대', '수육']
# 야채모듬
# ['야채모듬']
# 후라이드모듬감자
# ['후라이드모듬', '감자']
# 후라이드모듬소세지
# ['후라이드모듬소세지']
# 모듬삼합
# ['모듬삼합']
# 멍게모듬
# ['멍게모듬']
# 모듬치즈샐러드
# ['모듬', '치즈', '샐러드']
# 마라해산물모듬
# ['마라해산물모듬']
# 카오위류야채모듬추가
# ['카오위류야채모듬추가']
# 롱샤모듬
# ['롱샤모듬']
# 돈모듬
# ['돈모듬']
# 모듬초밥메밀또는우동새우튀김
# ['모듬', '초밥', '메밀또는', '우동', '새우튀김']
# 모듬사시미서더리탕새우튀김
# ['모듬사시미서더리탕새', '우튀김']
# 떡볶이모듬
# ['떡볶이', '모듬']
# 한양모듬떡볶이
# ['한양모듬', '떡볶이']
# 모듬구이고등어시래기찌개
# ['모듬구이고등어시래기', '찌개']
# 모듬치즈
# ['모듬', '치즈']
# 모듬젓
# ['모듬젓']
# 모듬라면
# ['모듬', '라면']
# 듬뿍김밥
# ['듬뿍', '김밥']
# 훈제모듬
# ['훈제모듬']
# 치즈듬뿍계란말이
# ['치즈', '듬뿍계란말이']
# 모듬세꼬시
# ['모듬세꼬시']
# 생와사비게살듬뿍김밥
# ['생와사비게살듬뿍', '김밥']
# 자몽듬뿍차
# ['자몽듬뿍차']
# 레몬듬뿍차
# ['레몬듬뿍차']
# 모듬회사시미
# ['모듬회사시미']
# 홍쉐프모듬스테이크세트
# ['홍쉐프모듬', '스테이크', '세트']
# 참치모듬회
# ['참치모듬회']
# 모듬소고기쌀국수
# ['모듬소고기', '쌀국수']
# 수제모듬튀김
# ['수제모듬튀김']
# 야훠모듬
# ['야훠모듬']
# 견과모듬
# ['견과', '모듬']
# 모듬햄
# ['모듬햄']
# 양곱창모듬전골
# ['양곱창모듬전골']
# 특본모듬스테이크
# ['특본모듬', '스테이크']
# 본모듬스테이트
# ['본모듬스테이트']
# 등심모듬스테이크
# ['등심모듬', '스테이크']
# 잔치집모듬전
# ['잔치집모듬전']
# 셋트모듬전식
# ['셋트모듬전식']
# 셋트모듬전식인추가
# ['셋트모듬전식인추가']
# 특선모듬전식
# ['특선모듬전식']
# 특선모듬전식인추가
# ['특선모듬전식인추가']
# 돼지머리고기모듬
# ['돼지머리고기모듬']
# 모듬에피타이저
# ['모듬에피타이저']
# 믿음직숯불모듬구이
# ['믿음직숯불모듬구이']
# 모듬버섯추가
# ['모듬버섯추가']
# 모듬찜샤브샤브
# ['모듬찜', '샤브샤브']
# 제주돼지모듬
# ['제주돼지모듬']
# 가마보꼬모듬어묵탕
# ['가마보꼬모듬', '어묵탕']
# 모듬가스
# ['모듬가스']
# 모듬감자치즈스틱
# ['모듬', '감자', '치즈스틱']
# 모듬튀김플레이트
# ['모듬튀김플레이트']
# 한우모듬구이정식
# ['한우모듬구이정식']
# 모듬안주물회
# ['모듬안주', '물회']
# 모듬토핑
# ['모듬토핑']
# 모듬초밥튀김우동
# ['모듬', '초밥', '튀김', '우동']
# 모듬야채쇠고기볶음
# ['모듬야채쇠고기볶음']
# 그릴모듬소세지감자튀김
# ['그릴모듬소세지', '감자튀김']
# 치즈듬뿍돈까스
# ['치즈', '듬뿍돈까스']
# 모듬세트대
# ['모듬세트대']
# 모듬세트중
# ['모듬세트중']
# 한우생듬심
# ['한우생듬심']
# 모듬홍어
# ['모듬홍어']
# 모듬야채꼬치
# ['모듬야채꼬치']
# 찰진모듬셋트
# ['찰진모듬셋트']
# 고기듬뿍덮밥
# ['고기듬뿍', '덮밥']
# 칠리커리소세지모듬
# ['칠리커리소세지모듬']
# 모듬부대찌개치즈떡사리스팸
# ['모듬', '부대찌개', '치즈', '떡사리스팸']
# 크래미듬뿍김밥
# ['크래미듬뿍', '김밥']
# 날치알듬뿍셀프주먹밥
# ['날치알듬뿍셀프', '주먹밥']
# 모듬프라이
# ['모듬프라이']
# 야채듬뿍쫄면
# ['야채듬뿍', '쫄면']
# 갈빗살모듬
# ['갈빗살모듬']
# 수육모듬
# ['수육', '모듬']
# 차돌구이부채살구이스페셜모듬샤브샤브로변경
# ['차돌구이부채살구이스', '페셜모듬', '샤브샤브', '로변경']
# 치즈듬뿍볶음밥
# ['치즈', '듬뿍', '볶음밥']
# 모듬직화
# ['모듬직화']
# 바베큐모듬플래터
# ['바베큐모듬플래터']
# 모듬치즈플레이트
# ['모듬', '치즈', '플레이트']
# 제주흑돈모듬세트
# ['제주흑돈모듬세트']
# 큰모듬만두
# ['큰모듬', '만두']
# 쌀모듬찐빵
# ['쌀모듬찐빵']
# 특모듬한판광어
# ['특모듬한판광어']
# 한돈모듬한판광어
# ['한돈모듬한판광어']
# 모듬한판광어
# ['모듬한판광어']
# 모듬회덮밥
# ['모듬', '회덮밥']
# 카이센동모듬
# ['카이센동모듬']
# 부산어묵모듬
# ['부산어묵모듬']
# 차차모듬플래터
# ['차차모듬플래터']
# 모듬샤브야채
# ['모듬샤브야채']
# 해산물모듬스페셜
# ['해산물모듬스페셜']
# 더먹어라모듬튀김
# ['더먹어라모듬튀김']
# 다먹어라모듬튀김
# ['다먹어라모듬튀김']
# 모듬골뱅이탕
# ['모듬골뱅이탕']
# 특해물모듬물회
# ['특해물모듬', '물회']
# 순대고기모듬
# ['순대', '고기모듬']
# 치즈듬뿍
# ['치즈', '듬뿍']
# 밤듬뿍
# ['밤듬뿍']
# 모듬안주
# ['모듬안주']
# 모듬부대구이
# ['모듬부대구이']
# 모듬부대
# ['모듬부대']
# 돈까스모듬떡볶이
# ['돈까스모듬', '떡볶이']
# 사시미모듬인
# ['사시미모듬인']
# 모듬계란말이
# ['모듬계란말이']
# 모듬추가
# ['모듬추가']
# 카레모듬덮밥
# ['카레모듬', '덮밥']
# 모듬편백찜
# ['모듬편백찜']
# 모듬콩콥샐러드
# ['모듬콩콥', '샐러드']
# 해물모듬오뎅
# ['해물모듬오뎅']
# 비원한우특선모듬
# ['비원한우특선모듬']
# 샐러드듬뿍클럽브런치
# ['샐러드', '듬뿍클럽브런치']
# 과즙듬뿍백자몽빙수
# ['과즙듬뿍백자몽', '빙수']
# 국산팥듬뿍인절미빙수
# ['국산팥듬뿍', '인절미', '빙수']
# 킹콩모듬사리세트인
# ['킹콩모듬사리세트인']
# 대포보듬전
# ['대포보듬전']
# 모듬특대
# ['모듬특대']
# 곱창모듬
# ['곱창모듬']
# 담소모듬
# ['담소모듬']
# 철판모듬바베큐
# ['철판모듬바베큐']
# 모듬포구이
# ['모듬포구이']
# 모듬직화볶음
# ['모듬직화볶음']
# 고기듬뿍설농탕
# ['고기듬뿍설농탕']
# 특모듬과일
# ['특모듬', '과일']
# 구운모듬소시지
# ['구운모듬', '소시지']
# 철판모듬수제소시지구이
# ['철판모듬수제', '소시지', '구이']
# 소시지모듬구이
# ['소시지', '모듬구이']
# 모듬돈가스
# ['모듬', '돈가스']
# 전복모듬삼합
# ['전복모듬삼합']
# 특선모듬꼬치종
# ['특선모듬꼬치종']
# 모듬버섯샌드위치
# ['모듬버섯', '샌드위치']
# 모듬사이드세트
# ['모듬사이드세트']
# 모듬막회
# ['모듬막회']
# 쭈꾸미모듬전골
# ['쭈꾸미모듬전골']
# 모듬된장찌개고기
# ['모듬', '된장찌개', '고기']
# 모듬전무한리필
# ['모듬전무한리필']
# 가족모듬
# ['가족모듬']
# 모듬불치즈닭
# ['모듬불', '치즈', '닭']
# 계절별모듬전
# ['계절별모듬전']
# 모듬냉면
# ['모듬', '냉면']
# 모듬버섯스파게티
# ['모듬버섯', '스파게티']
# 모듬한잎
# ['모듬한잎']
# 모듬대판
# ['모듬대판']
# 스페셜모듬초밥
# ['스페셜모듬', '초밥']
# 모듬어묵
# ['모듬어묵']
# 햄듬뿍샌드위치
# ['햄듬뿍', '샌드위치']
# 햄듬뿍샌드위치아메리카노
# ['햄듬뿍', '샌드위치', '아메리카노']
# 건강모듬낫또
# ['건강모듬낫또']
# 모듬고르케
# ['모듬고르케']
# 돌판모듬수육
# ['돌판모듬', '수육']
# 버섯모듬구이
# ['버섯모듬구이']
# 듬뿍참치
# ['듬뿍참치']
# 모듬가츠정식
# ['모듬가츠정식']
# 특모듬사시미
# ['특모듬사시미']
# 모듬부위
# ['모듬부위']
# 맛보기모듬
# ['맛보기모듬']
# 일품모듬요리
# ['일품모듬요리']
# 고릴라모듬샐러드
# ['고릴라모듬', '샐러드']
# 새우듬뿍파스타
# ['새우듬뿍파스타']
# 고릴라모듬튀김
# ['고릴라모듬튀김']
# 모듬굽다
# ['모듬굽다']
# 모듬스테이크인분추가
# ['모듬', '스테이크', '인분추가']
# 모듬나베세트
# ['모듬', '나베', '세트']
# 해물모듬직화
# ['해물모듬직화']
# 북촌큰모듬
# ['북촌큰모듬']
# 스페샬모듬세트평일디너
# ['스페샬모듬세트평일디', '너']
# 스페샬모듬세트평일런치
# ['스페샬모듬세트평일런', '치']
# 스페셜모듬회
# ['스페셜모듬회']
# 한우모듬스페셜
# ['한우모듬스페셜']
# 김말이모듬꼬치
# ['김말이모듬꼬치']
# 모듬셋트튀김
# ['모듬셋트튀김']
# 공만모듬마른안주
# ['공만모듬마른안주']
# 모듬순대국
# ['모듬', '순대국']
# 모듬오뎅탕오뎅
# ['모듬오뎅탕오뎅']
# 모듬오뎅탕해물
# ['모듬오뎅탕해물']
# 모듬오뎅탕우동
# ['모듬오뎅탕', '우동']
# 가지의마른안주모듬
# ['가지의마른안주모듬']
# 수제모듬가스
# ['수제모듬가스']
# 코스게요리모듬스페샬매운탕추가
# ['코스게요리모듬스페샬', '매운탕', '추가']
# 게요리모듬스페샬
# ['게요리모듬스페샬']
# 모듬생천초밥
# ['모듬생천', '초밥']
# 금일의모듬꼬치구이
# ['금일의모듬', '꼬치구이']
# 모듬보쌈홍어문어
# ['모듬보쌈홍어문어']
# 모듬보쌈홍어굴
# ['모듬보쌈홍어굴']
# 모듬보쌈문어굴
# ['모듬보쌈문어굴']
# 돈가스모듬튀김
# ['돈가스', '모듬튀김']
# 매운모듬수육
# ['매운모듬', '수육']
# 매운모듬낙지수육
# ['매운모듬낙지', '수육']

# %% [markdown]
# '듬' 문제는 해결되었다. 커스텀 사전만 잘 다듬고, 더 늘리기만 해도 토큰화 성능이 좋아질거라고 생각한다.

# %% [markdown]
# # 빈도수 비율 상관없이 마지막 토큰 = 카테고리

# %%
df['tokens'][0][-1]
# Out:
# '정식'

# %%
menu_cluster = {}

for i, tokens in enumerate(df['tokens']):
  menu_cluster[df['menu'][i]] = tokens[-1] ## 빈도수 비율 상관없이, 모든 메뉴명에서 마지막 토큰을 카테고리로 분류

# %%
# 분류된 메뉴를 DataFrame화 
df_menu = pd.DataFrame(columns=['title', 'category'], data=menu_cluster.items())
df_menu['category'].unique()
# Out:
# array(['정식', '면', '짬뽕', ..., '설화샥스핀', '자연송이죽생', '좌종당계'], dtype=object)

# %%
len(df_menu['category'].unique())
# Out:
# 17505

# %%
pd.set_option('display.max_row', 100)

# %%
df_menu.sample(100)
# Out:
#                     title  category
# 31238               고기통만두        만두
# 33891                 앞다리        다리
# 41301            크림치즈호두김밥        김밥
# 34922             카츠카레라이스     카레라이스
# 46590           빅떡갈비김치볶음밥         밥
# 31102            민족치킨청마치킨        치킨
# 10432               비빔설록면     비빔설록면
# 17090                 애플티         티
# 49975               라떼주문시       주문시
# 17924            마요떡갈비밥버거        버거
# 37889          하프문우메시소하이볼  문우메시소하이볼
# 17726                보드카퐁      보드카퐁
# 39596         마약콜드브루프라푸치노     프라푸치노
# 19570              스트로베리퀸         퀸
# 47527            호두꿀크림중새우        새우
# 32619             전복스끼다시종   전복스끼다시종
# 24113                삥탕쉐리      삥탕쉐리
# 31776          초코소프트아이스크림  소프트아이스크림
# 42078          달콤오렌지라떼샷추가       샷추가
# 46038               설농탕요리     설농탕요리
# 36742                대구곤이        곤이
# 32521             치즈허니브레드     허니브레드
# 13911                스지조림      스지조림
# 37302              삼겹소금구이        구이
# 41455           황금비율크림막걸리       막걸리
# 4898               해산물샐러드       샐러드
# 22013            김치두루치기두부        두부
# 26135           굿모닝굿브레드세트        세트
# 9417                  킬케니       킬케니
# 39228             바닐라초코라떼      초코라떼
# 33313              칠리가지튀김        튀김
# 8115                 조선콤보      조선콤보
# 28601            철판야채순대볶음      순대볶음
# 41686             양념새우장덮밥        덮밥
# 36588            초콜렛칩블렌디드      블렌디드
# 32664             한마리후라이드   한마리후라이드
# 4230                  불짬뽕        짬뽕
# 19741          제육볶음작은돈공기밥      돈공기밥
# 39821                대만죽엽      대만죽엽
# 44139             로제파제육볶음        볶음
# 5844                  게낙탕       게낙탕
# 3010                아우내순대        순대
# 31066              볶음김치규동        규동
# 18767               상하이깐풍     상하이깐풍
# 36245               풍미소갈비     풍미소갈비
# 36640              스팸김치찌개      김치찌개
# 2375              얼큰소고기무국        무국
# 4979               순살블랙마요        마요
# 36857              봉골레링귀니    봉골레링귀니
# 47547           오곡라떼바밤바라떼        라떼
# 3713                 매운짜장        짜장
# 36098              장스가라아게    장스가라아게
# 40071                라면계란        계란
# 5012               차돌용돌초밥        초밥
# 5664               레몬스파클링      스파클링
# 51383             김치해물오뎅탕       오뎅탕
# 31220               파탑불고기       불고기
# 32296               허브비빔밥       비빔밥
# 33953                소고기면         면
# 47304               화이트에일        에일
# 7619             고급뱃살모듬세트        세트
# 18002       세뇨리오드이니에스타바리카       바리카
# 44931               월넛크럼블       크럼블
# 24018                치즈볼개         개
# 7133                긴죠나마죠     긴죠나마죠
# 12721               대포주전자     대포주전자
# 5521            굽네허니멜로통다리        다리
# 13891  루꼴라를올린앤초비알리오올리오링귀네     리오링귀네
# 40869              매콤제육덮밥        덮밥
# 28233                 사오정       사오정
# 6628             깔라마레스플란차  깔라마레스플란차
# 51270              마구로타다키    마구로타다키
# 11331             안단테올리브빵         빵
# 656               프레지던트버거        버거
# 12111               화끈불대패     화끈불대패
# 47314              버터구이오땅      구이오땅
# 45001                아이스바         바
# 4118             한우매생이갈비탕       갈비탕
# 47804                굴해물찜       해물찜
# 36955              우유빛깔석화      빛깔석화
# 29781               레몬블랙티       블랙티
# 8322                추가흑돼지       흑돼지
# 8541             에비덴라이스커리        커리
# 24353                모든튀김      모든튀김
# 534                    복찜        복찜
# 9030                오단조개찜     오단조개찜
# 17199            통고구마크러스트   고구마크러스트
# 50403                   여         여
# 46533               돈까스커리     돈까스커리
# 24990             치즈홀릭닭갈비       닭갈비
# 41187             낙곱새새우튀김        튀김
# 21020              빨간양념치킨      양념치킨
# 9270             치킨카라아게벤또    카라아게벤또
# 45805                팥도넛츠         츠
# 9214                불갈비꼬지     불갈비꼬지
# 34831               플래인스콘        스콘
# 47113           배모히또샤인크러쉬       크러쉬
# 13609            생양념벌집껍데기     벌집껍데기
# 42475           체리담은베리스무디       스무디
# 35382                작은새우        새우

# %%
custom_dict_find_category = df_menu['category'].value_counts()

# %%
custom_dict_find_category.index
# Out:
# Index(['세트', '치킨', '추가', '라떼', '볶음', '덮밥', '샐러드', '김밥', '피자', '떡볶이',
#        ...
#        '라쥐루즈', '활가리비', '백골뱅이', '미레즈', '파미에피노누아', '펜폴즈맥스쉬라즈', '이기갈지공다스',
#        '러더포드힐메를로', '이데딧담', '좌종당계'],
#       dtype='object', length=17505)

# %%
count_1_list = [custom_dict_find_category.index[i] for i, x in enumerate(custom_dict_find_category) if x == 1]

# %%
count_1_list_menu = [df_menu[df_menu['category'] == x]['title'].iloc[0] for x in count_1_list]

# %%
df_count_1 = pd.DataFrame()

# %%
df_count_1['title'] = count_1_list_menu
df_count_1['category'] = count_1_list

# %%
df_count_1
# Out:
#             title    category
# 0      해초고등어해초추가시  해초고등어해초추가시
# 1         후라이드오뎅탕     후라이드오뎅탕
# 2            소꼬리찜        소꼬리찜
# 3              우신          우신
# 4             생둥심         생둥심
# ...           ...         ...
# 14619    펜폴즈맥스쉬라즈    펜폴즈맥스쉬라즈
# 14620     이기갈지공다스     이기갈지공다스
# 14621    러더포드힐메를로    러더포드힐메를로
# 14622        이데딧담        이데딧담
# 14623        좌종당계        좌종당계
#
# [14624 rows x 2 columns]

# %%
df_count_1.to_csv("back_token_count_1.csv")

# %%
df_menu[df_menu['category'] == '좌종당계']
# Out:
#       title category
# 51436  좌종당계     좌종당계

# %% [markdown]
# ### 생각할 부분
#
# - 단어 사전에 없을 경우, 그냥 메뉴명 전체가 카테고리가 된다.
#
# - 메뉴명은 결국 한정되어 있고, 표준화를 위해서는 어느정도 수작업이 필요한데 커스텀 사전을 우리가 직접 넣는다면?
#
# - 현재 내 판단으로는 위의 MaxScoreTokenizer에 넣을 커스텀 사전을 수작업을 통해 넣는게 좋다는 생각이 든다.

# %% [markdown]
# # 핵심 아이디어
# 1. 이전 토큰 종결 분류에서 계속된다
#
# 2. 특정 토큰과 가장 가까운 토큰을 몇 개 추린다
# ex) 해장국 => 뼈, 콩나물
#
# 3. 특정 토큰으로 분류된 음식명에 가까운 토큰이 포함되어 있나 조사한다
# ex) 뼈다귀 해장국 => 해장국으로 분류됨 + 뼈 토큰 포함
#
# 4. 그럼 그 음식명에 속성을 추가해준다
# ex) 뼈다귀 해장국 => 해장국 속성 + 뼈 속성
#
# 5. 두 속성이 동시에 포함된 음식명을 전체 음식 목록에서 찾는다
# ex) 해장국과 뼈가 동시에 포함된 음식명 = 뼈다귀 해장국
#
# 6. 세부 분류를 한다
# ex) 뼈해장국을 해장국 > 뼈해장국으로 분류

# %%
# 국밥을 예시로 시도해본다
df_menu[df_menu['category'] == '국밥']
# Out:
#          title category
# 19520   특미마라국밥       국밥
# 19521  시래기순대국밥       국밥
# 19522    매생이국밥       국밥
# 19523    아우내국밥       국밥
# 19524   얼큰차돌국밥       국밥
# ...        ...      ...
# 19709     선지국밥       국밥
# 19710    수구레국밥       국밥
# 19711     송이국밥       국밥
# 19712   얼큰순대국밥       국밥
# 19713      닭국밥       국밥
#
# [194 rows x 2 columns]

# %%
# 국밥 리스트 생성 
gookbab = df_menu[df_menu['category']=='국밥']['title'].tolist()
gookbab[:10]
# Out:
# ['특미마라국밥',
#  '시래기순대국밥',
#  '매생이국밥',
#  '아우내국밥',
#  '얼큰차돌국밥',
#  '순두부국밥',
#  '장터따로국밥',
#  '하노이국밥',
#  '내장섞어국밥',
#  '한우우거지국밥']

# %%
# 국밥 명사단위로 토큰화 후 리스트 내 리스트 제거 
gookbab_tokenized = [t.nouns(word) for word in gookbab]
gookbab_tokenized = [w for word in gookbab_tokenized for w in word]
gookbab_tokenized[:10]
# Out:
# ['특', '국밥', '시래기', '순대', '국밥', '생', '국밥', '아우', '국밥', '얼']

# %%
# 토큰화된 국밥 리스트 분석
import nltk
gookbab_ko = nltk.Text(gookbab_tokenized, name='국밥 토큰')

# %%
# 국밥 토큰 개수와 빈도 분석 
gookbab_similar = gookbab_ko.vocab().most_common(15)
len(gookbab_ko), gookbab_similar
# Out:
# (446,
#  [('국밥', 164),
#   ('순대', 19),
#   ('콩나물', 18),
#   ('얼', 15),
#   ('한우', 9),
#   ('소고기', 9),
#   ('장터', 8),
#   ('굴국밥', 8),
#   ('김치', 7),
#   ('장국밥', 7),
#   ('돼지국밥', 7),
#   ('시래기', 5),
#   ('우거지', 5),
#   ('고기', 5),
#   ('소머리국밥', 5)])

# %%
# 국밥 종류 생성
kind_of_gookbab = [value for value, num in gookbab_similar if len(value) != 1]
kind_of_gookbab
# Out:
# ['국밥',
#  '순대',
#  '콩나물',
#  '한우',
#  '소고기',
#  '장터',
#  '굴국밥',
#  '김치',
#  '장국밥',
#  '돼지국밥',
#  '시래기',
#  '우거지',
#  '고기',
#  '소머리국밥']

# %%
for token in kind_of_gookbab[1:]: #kind_of_gookbab[0] = '국밥'
  for menu in gookbab:
    if token in menu:
      print(f'{menu}: {token}')
# Out:
# 시래기순대국밥: 순대
# 부산순대국밥: 순대
# 순대고기국밥: 순대
# 순대국밥: 순대
# 매운고추순대국밥: 순대
# 순대만국밥: 순대
# 김치순대국밥: 순대
# 따로순대국밥: 순대
# 순대뽈살국밥: 순대
# 올순대국밥: 순대
# 토종순대국밥: 순대
# 우거지순대국밥: 순대
# 황태순대국밥: 순대
# 콩나물순대국밥: 순대
# 특매운순대국밥: 순대
# 찰순대국밥: 순대
# 순대지옥국밥: 순대
# 얼큰장순대국밥: 순대
# 사골순대국밥: 순대
# 고기순대섞어국밥: 순대
# 흰순대국밥: 순대
# 한우사골순대국밥: 순대
# 얼큰이순대국밥: 순대
# 매운순대국밥: 순대
# 특순대국밥: 순대
# 순대국국밥: 순대
# 장순대국밥: 순대
# 살고기순대국밥: 순대
# 순대섞어국밥: 순대
# 얼큰순대국밥: 순대
# 양지콩나물국밥: 콩나물
# 김치콩나물따로국밥: 콩나물
# 콩나물김치국밥: 콩나물
# 한우콩나물국밥: 콩나물
# 불고기콩나물국밥: 콩나물
# 황태콩나물국밥: 콩나물
# 전주콩나물국밥: 콩나물
# 콩나물따로국밥: 콩나물
# 콩나물순대국밥: 콩나물
# 어린이콩나물국밥: 콩나물
# 전주식콩나물국밥: 콩나물
# 김치콩나물국밥: 콩나물
# 굴콩나물국밥: 콩나물
# 콩나물국밥: 콩나물
# 따로굴콩나물국밥: 콩나물
# 전주끊이는식콩나물국밥: 콩나물
# 전주남부시장식콩나물국밥: 콩나물
# 콩나물황태해장국밥: 콩나물
# 한우우거지국밥: 한우
# 한우콩나물국밥: 한우
# 한우장국밥: 한우
# 한우소머리국밥: 한우
# 한우소국밥: 한우
# 한우사골순대국밥: 한우
# 한우장터국밥: 한우
# 한우얼큰소머리국밥: 한우
# 한우따로국밥: 한우
# 한우시골장터국밥: 한우
# 한우국밥: 한우
# 구월산소고기국밥: 소고기
# 얼큰소고기국밥: 소고기
# 소고기국밥: 소고기
# 연변소고기국밥: 소고기
# 소고기따로국밥: 소고기
# 장터소고기국밥: 소고기
# 양평소고기국밥: 소고기
# 한끼소고기국밥: 소고기
# 얼큰소고기가마솥국밥: 소고기
# 장터따로국밥: 장터
# 소뼈장터국밥: 장터
# 한우장터국밥: 장터
# 장터소고기국밥: 장터
# 장터국밥: 장터
# 한우시골장터국밥: 장터
# 시골장터국밥: 장터
# 장터소국밥: 장터
# 들깨굴국밥: 굴국밥
# 하얀굴국밥: 굴국밥
# 따로매생이굴국밥: 굴국밥
# 굴국밥: 굴국밥
# 매생이굴국밥: 굴국밥
# 통영굴국밥: 굴국밥
# 얼큰굴국밥: 굴국밥
# 따로굴국밥: 굴국밥
# 김치콩나물따로국밥: 김치
# 콩나물김치국밥: 김치
# 김치순대국밥: 김치
# 김치콩나물국밥: 김치
# 거창에서즐겨먹던김치국밥: 김치
# 김치국밥: 김치
# 김치따로국밥: 김치
# 일품내장국밥: 장국밥
# 시래기된장국밥: 장국밥
# 한우장국밥: 장국밥
# 수원고기집된장국밥: 장국밥
# 올내장국밥: 장국밥
# 쇠고기장국밥: 장국밥
# 따로내장국밥: 장국밥
# 내장국밥: 장국밥
# 다슬기장국밥: 장국밥
# 사골우거지된장국밥: 장국밥
# 콩나물황태해장국밥: 장국밥
# 돼지국밥: 돼지국밥
# 꿀돼지국밥: 돼지국밥
# 따로돼지국밥: 돼지국밥
# 부산돼지국밥: 돼지국밥
# 극상돼지국밥: 돼지국밥
# 시래기돼지국밥: 돼지국밥
# 얼큰돼지국밥: 돼지국밥
# 시래기순대국밥: 시래기
# 시래기된장국밥: 시래기
# 시래기따로국밥: 시래기
# 시래기국밥: 시래기
# 시래기돼지국밥: 시래기
# 한우우거지국밥: 우거지
# 얼큰우거지국밥: 우거지
# 우거지순대국밥: 우거지
# 우거지국밥: 우거지
# 사골우거지된장국밥: 우거지
# 순대고기국밥: 고기
# 구월산소고기국밥: 고기
# 얼큰소고기국밥: 고기
# 고기내장섞어국밥: 고기
# 소고기국밥: 고기
# 얼큰고기국밥: 고기
# 불고기콩나물국밥: 고기
# 수원고기집된장국밥: 고기
# 고기국밥: 고기
# 쇠고기장국밥: 고기
# 연변소고기국밥: 고기
# 고기순대섞어국밥: 고기
# 사골고기국밥: 고기
# 살고기국밥: 고기
# 돼지고기국밥: 고기
# 소고기따로국밥: 고기
# 장터소고기국밥: 고기
# 양평소고기국밥: 고기
# 머릿고기국밥: 고기
# 한끼소고기국밥: 고기
# 얼큰소고기가마솥국밥: 고기
# 살고기순대국밥: 고기
# 쇠고기국밥: 고기
# 소머리국밥: 소머리국밥
# 곤지암소머리국밥: 소머리국밥
# 한우소머리국밥: 소머리국밥
# 가마솥소머리국밥: 소머리국밥
# 한우얼큰소머리국밥: 소머리국밥
